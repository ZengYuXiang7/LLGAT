# %%
import numpy as np

"""
    0 con1 1 con3 2 max3 3 input 4 output 5 None
"""
op_name = ['con1', 'con3', 'max3', 'input', 'output', 'None']
"""
    Maximum Turbo Boost Frequency, Number of Cores, Number of Threads, Level 3 Cache, Maximum Memory Bandwidth
"""
device_fetures = ['CPU Clock Frequency', 'Maximum Turbo Boost Frequency', 'Number of Cores', 'Number of Threads', 'Level 3 Cache', ', Maximum Memory Bandwidth']

# %%
import torch
from utils.plotter import MetricsPlotter
from utils.logger import Logger
from utils.utils import set_settings
from data import experiment
from utils.config import get_config

args = get_config()
set_settings(args)
args.train_size = 200
# logger plotter
exper_detail = f"Dataset : {args.dataset.upper()}, Model : {args.model}, Train_size : {args.train_size}, Bs : {args.bs}, Rank : {args.rank}, "
exper_detail += f"Train Device : {args.train_device} "
log_filename = f'Model_{args.model}_T{args.train_size}_R{args.rank}'
log = Logger(log_filename, exper_detail, args)
plotter = MetricsPlotter(log_filename, args)
args.log = log
log(str(args.__dict__))
# Out:
# |2024-10-03 18:15:44| {
#      'att': 0, 'bs': 64, 'classification': False, 'cross': 0,
#      'dataset': cpu, 'debug': False, 'decay': 0.0001, 'density': 0.8,
#      'device': cpu, 'device_name': core-i7-7820x, 'epochs': 1000, 'eval_device': desktop-cpu-core-i9-13900k-fp32,
#      'experiment': False, 'graph_encoder': gat, 'heads': 8, 'inductive': False,
#      'llm': 1, 'logger': None, 'loss_func': L1Loss, 'lr': 0.001,
#      'model': ours, 'op_encoder': embed, 'optim': AdamW, 'order': 4,
#      'path': ./datasets/, 'patience': 100, 'program_test': False, 'rank': 100,
#      'record': True, 'retrain': False, 'rounds': 5, 'seed': 0,
#      'train_device': desktop-cpu-core-i7-7820x-fp32, 'train_size': 200, 'verbose': 0, 'visualize': True,
# }
# |2024-10-03 18:15:44| {'classification': False, 'visualize': True, 'inductive': False, 'bs': 64, 'lr': 0.001, 'decay': 0.0001, 'loss_func': 'L1Loss', 'optim': 'AdamW', 'path': './datasets/', 'dataset': 'cpu', 'train_size': 200, 'density': 0.8, 'logger': 'None', 'model': 'ours', 'rank': 100, 'retrain': False, 'seed': 0, 'rounds': 5, 'epochs': 1000, 'patience': 100, 'verbose': 0, 'device': 'cpu', 'debug': False, 'experiment': False, 'program_test': False, 'record': True, 'train_device': 'desktop-cpu-core-i7-7820x-fp32', 'device_name': 'core-i7-7820x', 'op_encoder': 'embed', 'graph_encoder': 'gat', 'order': 4, 'heads': 8, 'llm': 1, 'eval_device': 'desktop-cpu-core-i9-13900k-fp32', 'att': 0, 'cross': 0, 'log': <utils.logger.Logger object at 0x7fc9d0664250>}

# %%
from train_model import Model
from data import DataModule

# Initialize
exper = experiment(args)
datamodule = DataModule(exper, args)
model = Model(datamodule, args)
# Out:
# desktop-cpu-core-i7-7820x-fp32.pickle
# |2024-10-03 18:15:44| Train_length : 200 Valid_length : 1528 Test_length : 13556 Max_value : 0.01
# 加载存储数据 tensor([[0.6143, 0.2500, 0.5000, 0.2750, 0.3750]])

# %%
model.load_state_dict(torch.load(f'checkpoints/ours/Model_ours_cpu_S{args.train_size}_R100_round_2.pt', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
from tqdm import *
idx = 96
sample_input = datamodule.train_loader.dataset[idx]
graph, features, values = sample_input
features = features.reshape(1, -1)
print(graph, features)
from time import time 
t1 = time()
nums = 1000
for i in trange(nums):
    model(graph, features)
t2 = time()
print((t2 - t1) / nums)
# Out:
# Graph(num_nodes=9, num_edges=39,
#       ndata_schemes={}
#       edata_schemes={}) tensor([[5, 3, 1, 2, 2, 0, 0, 0, 4]])
# 100%|██████████| 1000/1000 [00:02<00:00, 357.87it/s]
# 0.0027961938381195067

# %%
model.model.llms.aug_data
# Out:
# tensor([[0.6143, 0.2500, 0.5000, 0.2750, 0.3750]], requires_grad=True)

# %%
from tqdm import trange


def get_embeds_importance(model, sample_input):
    import torch
    
    graph, features, values = sample_input
    features = features.reshape(1, -1).long()
    
    # 清除模型中所有参数的梯度
    model.zero_grad()
    
    # 确保 info_embeds 和 graph_embeds 的梯度可以计算
    batch_size = features.shape[0]
    info_embeds = model.model.llms(batch_size)
    graph_embeds = model.model.graph_encoder(graph, features)
    
    # 确保在前向传播之前设置 requires_grad=True
    info_embeds.requires_grad_(True)
    graph_embeds.requires_grad_(True)
    
    # 在非叶子张量上保留梯度
    info_embeds.retain_grad()
    graph_embeds.retain_grad()
    
    # 组合嵌入，进行前向传播
    embeds = torch.cat([graph_embeds, info_embeds], dim=1)
    output = model.model.predictor(embeds)
    
    # 使用人为定义的损失函数，比如对输出的简单加权平均
    loss = output.mean()  # 简单的均值作为损失
    
    # 反向传播计算损失的梯度
    loss.backward()
    
    # 获取两个嵌入的梯度并计算它们的重要性
    info_importance = info_embeds.grad.abs().sum().item()
    graph_importance = graph_embeds.grad.abs().sum().item()
    
    total_importance = info_importance + graph_importance
    graph_importance /= total_importance
    info_importance /= total_importance
    
    # print("LLMs Embeds Importance:", info_importance)
    # print("Graph Embeds Importance:", graph_importance)
    return graph_importance, info_importance

# 全局变量
llms_total, gread_total = 0, 0
total_samples = 0

# 处理训练集
for i in trange(len(datamodule.train_loader.dataset)):
    g, l = get_embeds_importance(model, sample_input=datamodule.train_loader.dataset[i])
    gread_total += g
    llms_total += l
total_samples += len(datamodule.train_loader.dataset)
llms_avg_train = llms_total / total_samples
gread_avg_train = gread_total / total_samples
print("LLMs Embeds Importance (Train):", llms_avg_train)
print("Graph Embeds Importance (Train):", gread_avg_train)

# # 处理验证集
# for i in trange(len(datamodule.valid_loader.dataset)):
#     g, l = get_embeds_importance(model, sample_input=datamodule.valid_loader.dataset[i])
#     gread_total += g
#     llms_total += l
# total_samples += len(datamodule.valid_loader.dataset)
# llms_avg_valid = llms_total / total_samples
# gread_avg_valid = gread_total / total_samples
# print("LLMs Embeds Importance (Train + Valid):", llms_avg_valid)
# print("Graph Embeds Importance (Train + Valid):", gread_avg_valid)
#
# # 处理测试集
# for i in trange(len(datamodule.test_loader.dataset)):
#     g, l = get_embeds_importance(model, sample_input=datamodule.test_loader.dataset[i])
#     gread_total += g
#     llms_total += l
# total_samples += len(datamodule.test_loader.dataset)
# llms_avg_test = llms_total / total_samples
# gread_avg_test = gread_total / total_samples
# print("LLMs Embeds Importance (All):", llms_avg_test)
# print("Graph Embeds Importance (All):", gread_avg_test)
# Out:
# 100%|██████████| 200/200 [00:01<00:00, 134.42it/s]
# LLMs Embeds Importance (Train): 0.38952354947415574
# Graph Embeds Importance (Train): 0.6104764505258443

# %%
def get_device_feature_importance(model, sample_input):
    import torch
    
    # 清除模型中所有参数的梯度
    model.zero_grad()
    
    graph, features, values = sample_input
    
    # 获取 info_importance
    _, info_importance = get_embeds_importance(model, sample_input)
    
    # 设置 aug_data 为 requires_grad=True
    model.model.llms.aug_data.requires_grad = True
    
    # 前向传播计算输出 y
    features = features.reshape(1, -1).long()
    output = model(graph, features)
    
    # 反向传播计算每个输入特征的梯度
    output.backward()
    
    # 获取 aug_data 的梯度并计算重要性
    aug_data_importance = model.model.llms.aug_data.grad.abs()
    
    # 标准化重要性，使其和为1
    aug_data_importance = aug_data_importance / aug_data_importance.sum()
    
    # 打印 aug_data 中每个元素的重要性
    each_device_info_importance = aug_data_importance.squeeze(0).detach().numpy()
    print("Overall importance of each element in aug_data to the model:")
    for i in range(len(each_device_info_importance)):
        print(f"LLMs features-{device_fetures[i]} : {each_device_info_importance[i]:.4f}", )
    # 计算每个 aug_data 元素在整个模型中的重要性
    # each_device_info_importance = info_importance * aug_data_importance
    # each_device_info_importance = each_device_info_importance.squeeze(0).detach().numpy()
    # print("Overall importance of each element in aug_data to the model:")
    # for i in range(len(each_device_info_importance)):
    #     print(f"LLMs features-{device_fetures[i]} : {each_device_info_importance[i]:.4f}", )
    # print('-' * 80)

    return each_device_info_importance

all_device_importance = np.zeros(5)
for i in range(len(datamodule.train_loader.dataset)):
    temp = get_device_feature_importance(model = model, sample_input = datamodule.train_loader.dataset[i])
    all_device_importance += temp 
all_device_importance /= len(datamodule.train_loader.dataset)
# Out:
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5336
# LLMs features-Maximum Turbo Boost Frequency : 0.0102
# LLMs features-Number of Cores : 0.2489
# LLMs features-Number of Threads : 0.0555
# LLMs features-Level 3 Cache : 0.1519
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5329
# LLMs features-Maximum Turbo Boost Frequency : 0.0096
# LLMs features-Number of Cores : 0.2498
# LLMs features-Number of Threads : 0.0545
# LLMs features-Level 3 Cache : 0.1532
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5316
# LLMs features-Maximum Turbo Boost Frequency : 0.0101
# LLMs features-Number of Cores : 0.2496
# LLMs features-Number of Threads : 0.0538
# LLMs features-Level 3 Cache : 0.1549
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5302
# LLMs features-Maximum Turbo Boost Frequency : 0.0111
# LLMs features-Number of Cores : 0.2486
# LLMs features-Number of Threads : 0.0530
# LLMs features-Level 3 Cache : 0.1571
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5288
# LLMs features-Maximum Turbo Boost Frequency : 0.0122
# LLMs features-Number of Cores : 0.2473
# LLMs features-Number of Threads : 0.0523
# LLMs features-Level 3 Cache : 0.1594
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5272
# LLMs features-Maximum Turbo Boost Frequency : 0.0136
# LLMs features-Number of Cores : 0.2459
# LLMs features-Number of Threads : 0.0516
# LLMs features-Level 3 Cache : 0.1617
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5266
# LLMs features-Maximum Turbo Boost Frequency : 0.0133
# LLMs features-Number of Cores : 0.2465
# LLMs features-Number of Threads : 0.0507
# LLMs features-Level 3 Cache : 0.1630
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5253
# LLMs features-Maximum Turbo Boost Frequency : 0.0139
# LLMs features-Number of Cores : 0.2459
# LLMs features-Number of Threads : 0.0500
# LLMs features-Level 3 Cache : 0.1649
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5246
# LLMs features-Maximum Turbo Boost Frequency : 0.0134
# LLMs features-Number of Cores : 0.2469
# LLMs features-Number of Threads : 0.0491
# LLMs features-Level 3 Cache : 0.1661
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5233
# LLMs features-Maximum Turbo Boost Frequency : 0.0142
# LLMs features-Number of Cores : 0.2460
# LLMs features-Number of Threads : 0.0484
# LLMs features-Level 3 Cache : 0.1681
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5226
# LLMs features-Maximum Turbo Boost Frequency : 0.0137
# LLMs features-Number of Cores : 0.2469
# LLMs features-Number of Threads : 0.0475
# LLMs features-Level 3 Cache : 0.1693
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5217
# LLMs features-Maximum Turbo Boost Frequency : 0.0139
# LLMs features-Number of Cores : 0.2468
# LLMs features-Number of Threads : 0.0467
# LLMs features-Level 3 Cache : 0.1708
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5206
# LLMs features-Maximum Turbo Boost Frequency : 0.0142
# LLMs features-Number of Cores : 0.2470
# LLMs features-Number of Threads : 0.0461
# LLMs features-Level 3 Cache : 0.1721
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5198
# LLMs features-Maximum Turbo Boost Frequency : 0.0145
# LLMs features-Number of Cores : 0.2471
# LLMs features-Number of Threads : 0.0453
# LLMs features-Level 3 Cache : 0.1733
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5194
# LLMs features-Maximum Turbo Boost Frequency : 0.0140
# LLMs features-Number of Cores : 0.2484
# LLMs features-Number of Threads : 0.0438
# LLMs features-Level 3 Cache : 0.1744
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5187
# LLMs features-Maximum Turbo Boost Frequency : 0.0134
# LLMs features-Number of Cores : 0.2495
# LLMs features-Number of Threads : 0.0429
# LLMs features-Level 3 Cache : 0.1756
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5175
# LLMs features-Maximum Turbo Boost Frequency : 0.0142
# LLMs features-Number of Cores : 0.2486
# LLMs features-Number of Threads : 0.0422
# LLMs features-Level 3 Cache : 0.1775
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5168
# LLMs features-Maximum Turbo Boost Frequency : 0.0134
# LLMs features-Number of Cores : 0.2499
# LLMs features-Number of Threads : 0.0413
# LLMs features-Level 3 Cache : 0.1786
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5156
# LLMs features-Maximum Turbo Boost Frequency : 0.0141
# LLMs features-Number of Cores : 0.2493
# LLMs features-Number of Threads : 0.0407
# LLMs features-Level 3 Cache : 0.1803
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5152
# LLMs features-Maximum Turbo Boost Frequency : 0.0138
# LLMs features-Number of Cores : 0.2504
# LLMs features-Number of Threads : 0.0398
# LLMs features-Level 3 Cache : 0.1809
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5145
# LLMs features-Maximum Turbo Boost Frequency : 0.0137
# LLMs features-Number of Cores : 0.2504
# LLMs features-Number of Threads : 0.0390
# LLMs features-Level 3 Cache : 0.1823
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5139
# LLMs features-Maximum Turbo Boost Frequency : 0.0139
# LLMs features-Number of Cores : 0.2502
# LLMs features-Number of Threads : 0.0382
# LLMs features-Level 3 Cache : 0.1838
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5127
# LLMs features-Maximum Turbo Boost Frequency : 0.0146
# LLMs features-Number of Cores : 0.2496
# LLMs features-Number of Threads : 0.0376
# LLMs features-Level 3 Cache : 0.1855
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5117
# LLMs features-Maximum Turbo Boost Frequency : 0.0149
# LLMs features-Number of Cores : 0.2497
# LLMs features-Number of Threads : 0.0370
# LLMs features-Level 3 Cache : 0.1867
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5105
# LLMs features-Maximum Turbo Boost Frequency : 0.0156
# LLMs features-Number of Cores : 0.2490
# LLMs features-Number of Threads : 0.0365
# LLMs features-Level 3 Cache : 0.1884
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5092
# LLMs features-Maximum Turbo Boost Frequency : 0.0169
# LLMs features-Number of Cores : 0.2476
# LLMs features-Number of Threads : 0.0359
# LLMs features-Level 3 Cache : 0.1904
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5077
# LLMs features-Maximum Turbo Boost Frequency : 0.0185
# LLMs features-Number of Cores : 0.2459
# LLMs features-Number of Threads : 0.0353
# LLMs features-Level 3 Cache : 0.1926
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5071
# LLMs features-Maximum Turbo Boost Frequency : 0.0186
# LLMs features-Number of Cores : 0.2457
# LLMs features-Number of Threads : 0.0345
# LLMs features-Level 3 Cache : 0.1940
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5060
# LLMs features-Maximum Turbo Boost Frequency : 0.0191
# LLMs features-Number of Cores : 0.2456
# LLMs features-Number of Threads : 0.0340
# LLMs features-Level 3 Cache : 0.1953
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5045
# LLMs features-Maximum Turbo Boost Frequency : 0.0209
# LLMs features-Number of Cores : 0.2435
# LLMs features-Number of Threads : 0.0333
# LLMs features-Level 3 Cache : 0.1979
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5034
# LLMs features-Maximum Turbo Boost Frequency : 0.0218
# LLMs features-Number of Cores : 0.2424
# LLMs features-Number of Threads : 0.0327
# LLMs features-Level 3 Cache : 0.1996
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5024
# LLMs features-Maximum Turbo Boost Frequency : 0.0225
# LLMs features-Number of Cores : 0.2418
# LLMs features-Number of Threads : 0.0322
# LLMs features-Level 3 Cache : 0.2012
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5018
# LLMs features-Maximum Turbo Boost Frequency : 0.0226
# LLMs features-Number of Cores : 0.2417
# LLMs features-Number of Threads : 0.0315
# LLMs features-Level 3 Cache : 0.2025
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.5009
# LLMs features-Maximum Turbo Boost Frequency : 0.0228
# LLMs features-Number of Cores : 0.2418
# LLMs features-Number of Threads : 0.0309
# LLMs features-Level 3 Cache : 0.2036
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4997
# LLMs features-Maximum Turbo Boost Frequency : 0.0240
# LLMs features-Number of Cores : 0.2406
# LLMs features-Number of Threads : 0.0305
# LLMs features-Level 3 Cache : 0.2053
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4990
# LLMs features-Maximum Turbo Boost Frequency : 0.0232
# LLMs features-Number of Cores : 0.2418
# LLMs features-Number of Threads : 0.0296
# LLMs features-Level 3 Cache : 0.2064
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4984
# LLMs features-Maximum Turbo Boost Frequency : 0.0225
# LLMs features-Number of Cores : 0.2430
# LLMs features-Number of Threads : 0.0287
# LLMs features-Level 3 Cache : 0.2075
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4970
# LLMs features-Maximum Turbo Boost Frequency : 0.0239
# LLMs features-Number of Cores : 0.2414
# LLMs features-Number of Threads : 0.0281
# LLMs features-Level 3 Cache : 0.2096
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4961
# LLMs features-Maximum Turbo Boost Frequency : 0.0246
# LLMs features-Number of Cores : 0.2407
# LLMs features-Number of Threads : 0.0276
# LLMs features-Level 3 Cache : 0.2110
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4954
# LLMs features-Maximum Turbo Boost Frequency : 0.0241
# LLMs features-Number of Cores : 0.2415
# LLMs features-Number of Threads : 0.0268
# LLMs features-Level 3 Cache : 0.2121
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4945
# LLMs features-Maximum Turbo Boost Frequency : 0.0245
# LLMs features-Number of Cores : 0.2413
# LLMs features-Number of Threads : 0.0264
# LLMs features-Level 3 Cache : 0.2133
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4935
# LLMs features-Maximum Turbo Boost Frequency : 0.0253
# LLMs features-Number of Cores : 0.2404
# LLMs features-Number of Threads : 0.0259
# LLMs features-Level 3 Cache : 0.2149
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4924
# LLMs features-Maximum Turbo Boost Frequency : 0.0264
# LLMs features-Number of Cores : 0.2392
# LLMs features-Number of Threads : 0.0254
# LLMs features-Level 3 Cache : 0.2165
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4920
# LLMs features-Maximum Turbo Boost Frequency : 0.0261
# LLMs features-Number of Cores : 0.2402
# LLMs features-Number of Threads : 0.0247
# LLMs features-Level 3 Cache : 0.2170
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4911
# LLMs features-Maximum Turbo Boost Frequency : 0.0267
# LLMs features-Number of Cores : 0.2396
# LLMs features-Number of Threads : 0.0242
# LLMs features-Level 3 Cache : 0.2184
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4901
# LLMs features-Maximum Turbo Boost Frequency : 0.0275
# LLMs features-Number of Cores : 0.2386
# LLMs features-Number of Threads : 0.0238
# LLMs features-Level 3 Cache : 0.2199
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4892
# LLMs features-Maximum Turbo Boost Frequency : 0.0283
# LLMs features-Number of Cores : 0.2378
# LLMs features-Number of Threads : 0.0233
# LLMs features-Level 3 Cache : 0.2214
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4892
# LLMs features-Maximum Turbo Boost Frequency : 0.0285
# LLMs features-Number of Cores : 0.2377
# LLMs features-Number of Threads : 0.0235
# LLMs features-Level 3 Cache : 0.2211
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4879
# LLMs features-Maximum Turbo Boost Frequency : 0.0298
# LLMs features-Number of Cores : 0.2363
# LLMs features-Number of Threads : 0.0230
# LLMs features-Level 3 Cache : 0.2230
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4875
# LLMs features-Maximum Turbo Boost Frequency : 0.0296
# LLMs features-Number of Cores : 0.2365
# LLMs features-Number of Threads : 0.0223
# LLMs features-Level 3 Cache : 0.2241
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4870
# LLMs features-Maximum Turbo Boost Frequency : 0.0295
# LLMs features-Number of Cores : 0.2367
# LLMs features-Number of Threads : 0.0216
# LLMs features-Level 3 Cache : 0.2252
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4861
# LLMs features-Maximum Turbo Boost Frequency : 0.0302
# LLMs features-Number of Cores : 0.2359
# LLMs features-Number of Threads : 0.0212
# LLMs features-Level 3 Cache : 0.2266
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4854
# LLMs features-Maximum Turbo Boost Frequency : 0.0304
# LLMs features-Number of Cores : 0.2358
# LLMs features-Number of Threads : 0.0207
# LLMs features-Level 3 Cache : 0.2277
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4846
# LLMs features-Maximum Turbo Boost Frequency : 0.0310
# LLMs features-Number of Cores : 0.2352
# LLMs features-Number of Threads : 0.0202
# LLMs features-Level 3 Cache : 0.2290
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4841
# LLMs features-Maximum Turbo Boost Frequency : 0.0308
# LLMs features-Number of Cores : 0.2355
# LLMs features-Number of Threads : 0.0196
# LLMs features-Level 3 Cache : 0.2300
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4837
# LLMs features-Maximum Turbo Boost Frequency : 0.0310
# LLMs features-Number of Cores : 0.2353
# LLMs features-Number of Threads : 0.0189
# LLMs features-Level 3 Cache : 0.2311
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4834
# LLMs features-Maximum Turbo Boost Frequency : 0.0305
# LLMs features-Number of Cores : 0.2365
# LLMs features-Number of Threads : 0.0175
# LLMs features-Level 3 Cache : 0.2321
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4825
# LLMs features-Maximum Turbo Boost Frequency : 0.0312
# LLMs features-Number of Cores : 0.2358
# LLMs features-Number of Threads : 0.0171
# LLMs features-Level 3 Cache : 0.2334
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4821
# LLMs features-Maximum Turbo Boost Frequency : 0.0309
# LLMs features-Number of Cores : 0.2363
# LLMs features-Number of Threads : 0.0164
# LLMs features-Level 3 Cache : 0.2344
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4815
# LLMs features-Maximum Turbo Boost Frequency : 0.0305
# LLMs features-Number of Cores : 0.2369
# LLMs features-Number of Threads : 0.0157
# LLMs features-Level 3 Cache : 0.2354
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4815
# LLMs features-Maximum Turbo Boost Frequency : 0.0306
# LLMs features-Number of Cores : 0.2368
# LLMs features-Number of Threads : 0.0158
# LLMs features-Level 3 Cache : 0.2353
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4811
# LLMs features-Maximum Turbo Boost Frequency : 0.0308
# LLMs features-Number of Cores : 0.2366
# LLMs features-Number of Threads : 0.0151
# LLMs features-Level 3 Cache : 0.2363
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4807
# LLMs features-Maximum Turbo Boost Frequency : 0.0307
# LLMs features-Number of Cores : 0.2368
# LLMs features-Number of Threads : 0.0145
# LLMs features-Level 3 Cache : 0.2374
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4801
# LLMs features-Maximum Turbo Boost Frequency : 0.0300
# LLMs features-Number of Cores : 0.2379
# LLMs features-Number of Threads : 0.0136
# LLMs features-Level 3 Cache : 0.2384
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4796
# LLMs features-Maximum Turbo Boost Frequency : 0.0299
# LLMs features-Number of Cores : 0.2380
# LLMs features-Number of Threads : 0.0130
# LLMs features-Level 3 Cache : 0.2395
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4788
# LLMs features-Maximum Turbo Boost Frequency : 0.0305
# LLMs features-Number of Cores : 0.2374
# LLMs features-Number of Threads : 0.0126
# LLMs features-Level 3 Cache : 0.2407
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4783
# LLMs features-Maximum Turbo Boost Frequency : 0.0301
# LLMs features-Number of Cores : 0.2381
# LLMs features-Number of Threads : 0.0119
# LLMs features-Level 3 Cache : 0.2417
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4775
# LLMs features-Maximum Turbo Boost Frequency : 0.0305
# LLMs features-Number of Cores : 0.2378
# LLMs features-Number of Threads : 0.0115
# LLMs features-Level 3 Cache : 0.2428
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4767
# LLMs features-Maximum Turbo Boost Frequency : 0.0308
# LLMs features-Number of Cores : 0.2377
# LLMs features-Number of Threads : 0.0111
# LLMs features-Level 3 Cache : 0.2437
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4762
# LLMs features-Maximum Turbo Boost Frequency : 0.0308
# LLMs features-Number of Cores : 0.2377
# LLMs features-Number of Threads : 0.0105
# LLMs features-Level 3 Cache : 0.2448
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4758
# LLMs features-Maximum Turbo Boost Frequency : 0.0309
# LLMs features-Number of Cores : 0.2375
# LLMs features-Number of Threads : 0.0099
# LLMs features-Level 3 Cache : 0.2459
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4753
# LLMs features-Maximum Turbo Boost Frequency : 0.0306
# LLMs features-Number of Cores : 0.2384
# LLMs features-Number of Threads : 0.0092
# LLMs features-Level 3 Cache : 0.2464
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4749
# LLMs features-Maximum Turbo Boost Frequency : 0.0303
# LLMs features-Number of Cores : 0.2389
# LLMs features-Number of Threads : 0.0085
# LLMs features-Level 3 Cache : 0.2474
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4741
# LLMs features-Maximum Turbo Boost Frequency : 0.0309
# LLMs features-Number of Cores : 0.2382
# LLMs features-Number of Threads : 0.0082
# LLMs features-Level 3 Cache : 0.2486
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4735
# LLMs features-Maximum Turbo Boost Frequency : 0.0302
# LLMs features-Number of Cores : 0.2394
# LLMs features-Number of Threads : 0.0074
# LLMs features-Level 3 Cache : 0.2496
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4727
# LLMs features-Maximum Turbo Boost Frequency : 0.0304
# LLMs features-Number of Cores : 0.2396
# LLMs features-Number of Threads : 0.0070
# LLMs features-Level 3 Cache : 0.2503
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4727
# LLMs features-Maximum Turbo Boost Frequency : 0.0306
# LLMs features-Number of Cores : 0.2395
# LLMs features-Number of Threads : 0.0072
# LLMs features-Level 3 Cache : 0.2501
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4719
# LLMs features-Maximum Turbo Boost Frequency : 0.0308
# LLMs features-Number of Cores : 0.2396
# LLMs features-Number of Threads : 0.0068
# LLMs features-Level 3 Cache : 0.2509
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4714
# LLMs features-Maximum Turbo Boost Frequency : 0.0305
# LLMs features-Number of Cores : 0.2401
# LLMs features-Number of Threads : 0.0061
# LLMs features-Level 3 Cache : 0.2519
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4707
# LLMs features-Maximum Turbo Boost Frequency : 0.0309
# LLMs features-Number of Cores : 0.2398
# LLMs features-Number of Threads : 0.0058
# LLMs features-Level 3 Cache : 0.2529
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4697
# LLMs features-Maximum Turbo Boost Frequency : 0.0322
# LLMs features-Number of Cores : 0.2381
# LLMs features-Number of Threads : 0.0054
# LLMs features-Level 3 Cache : 0.2546
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4696
# LLMs features-Maximum Turbo Boost Frequency : 0.0324
# LLMs features-Number of Cores : 0.2381
# LLMs features-Number of Threads : 0.0056
# LLMs features-Level 3 Cache : 0.2543
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4692
# LLMs features-Maximum Turbo Boost Frequency : 0.0321
# LLMs features-Number of Cores : 0.2389
# LLMs features-Number of Threads : 0.0049
# LLMs features-Level 3 Cache : 0.2549
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4686
# LLMs features-Maximum Turbo Boost Frequency : 0.0317
# LLMs features-Number of Cores : 0.2397
# LLMs features-Number of Threads : 0.0042
# LLMs features-Level 3 Cache : 0.2559
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4679
# LLMs features-Maximum Turbo Boost Frequency : 0.0324
# LLMs features-Number of Cores : 0.2389
# LLMs features-Number of Threads : 0.0039
# LLMs features-Level 3 Cache : 0.2570
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4672
# LLMs features-Maximum Turbo Boost Frequency : 0.0330
# LLMs features-Number of Cores : 0.2381
# LLMs features-Number of Threads : 0.0036
# LLMs features-Level 3 Cache : 0.2581
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4668
# LLMs features-Maximum Turbo Boost Frequency : 0.0330
# LLMs features-Number of Cores : 0.2382
# LLMs features-Number of Threads : 0.0030
# LLMs features-Level 3 Cache : 0.2591
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4661
# LLMs features-Maximum Turbo Boost Frequency : 0.0332
# LLMs features-Number of Cores : 0.2383
# LLMs features-Number of Threads : 0.0027
# LLMs features-Level 3 Cache : 0.2598
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4655
# LLMs features-Maximum Turbo Boost Frequency : 0.0326
# LLMs features-Number of Cores : 0.2392
# LLMs features-Number of Threads : 0.0019
# LLMs features-Level 3 Cache : 0.2608
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4648
# LLMs features-Maximum Turbo Boost Frequency : 0.0329
# LLMs features-Number of Cores : 0.2391
# LLMs features-Number of Threads : 0.0016
# LLMs features-Level 3 Cache : 0.2616
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4627
# LLMs features-Maximum Turbo Boost Frequency : 0.0355
# LLMs features-Number of Cores : 0.2364
# LLMs features-Number of Threads : 0.0016
# LLMs features-Level 3 Cache : 0.2638
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4620
# LLMs features-Maximum Turbo Boost Frequency : 0.0358
# LLMs features-Number of Cores : 0.2364
# LLMs features-Number of Threads : 0.0013
# LLMs features-Level 3 Cache : 0.2646
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4614
# LLMs features-Maximum Turbo Boost Frequency : 0.0361
# LLMs features-Number of Cores : 0.2360
# LLMs features-Number of Threads : 0.0010
# LLMs features-Level 3 Cache : 0.2655
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4608
# LLMs features-Maximum Turbo Boost Frequency : 0.0359
# LLMs features-Number of Cores : 0.2365
# LLMs features-Number of Threads : 0.0004
# LLMs features-Level 3 Cache : 0.2664
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4600
# LLMs features-Maximum Turbo Boost Frequency : 0.0370
# LLMs features-Number of Cores : 0.2351
# LLMs features-Number of Threads : 0.0001
# LLMs features-Level 3 Cache : 0.2679
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4590
# LLMs features-Maximum Turbo Boost Frequency : 0.0380
# LLMs features-Number of Cores : 0.2339
# LLMs features-Number of Threads : 0.0002
# LLMs features-Level 3 Cache : 0.2689
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4581
# LLMs features-Maximum Turbo Boost Frequency : 0.0388
# LLMs features-Number of Cores : 0.2328
# LLMs features-Number of Threads : 0.0004
# LLMs features-Level 3 Cache : 0.2699
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4571
# LLMs features-Maximum Turbo Boost Frequency : 0.0384
# LLMs features-Number of Cores : 0.2330
# LLMs features-Number of Threads : 0.0010
# LLMs features-Level 3 Cache : 0.2704
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4562
# LLMs features-Maximum Turbo Boost Frequency : 0.0387
# LLMs features-Number of Cores : 0.2326
# LLMs features-Number of Threads : 0.0013
# LLMs features-Level 3 Cache : 0.2711
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4553
# LLMs features-Maximum Turbo Boost Frequency : 0.0384
# LLMs features-Number of Cores : 0.2328
# LLMs features-Number of Threads : 0.0019
# LLMs features-Level 3 Cache : 0.2717
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4545
# LLMs features-Maximum Turbo Boost Frequency : 0.0389
# LLMs features-Number of Cores : 0.2320
# LLMs features-Number of Threads : 0.0021
# LLMs features-Level 3 Cache : 0.2725
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4530
# LLMs features-Maximum Turbo Boost Frequency : 0.0385
# LLMs features-Number of Cores : 0.2325
# LLMs features-Number of Threads : 0.0034
# LLMs features-Level 3 Cache : 0.2727
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4522
# LLMs features-Maximum Turbo Boost Frequency : 0.0388
# LLMs features-Number of Cores : 0.2320
# LLMs features-Number of Threads : 0.0036
# LLMs features-Level 3 Cache : 0.2734
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4511
# LLMs features-Maximum Turbo Boost Frequency : 0.0385
# LLMs features-Number of Cores : 0.2322
# LLMs features-Number of Threads : 0.0042
# LLMs features-Level 3 Cache : 0.2740
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4501
# LLMs features-Maximum Turbo Boost Frequency : 0.0380
# LLMs features-Number of Cores : 0.2326
# LLMs features-Number of Threads : 0.0049
# LLMs features-Level 3 Cache : 0.2745
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4493
# LLMs features-Maximum Turbo Boost Frequency : 0.0386
# LLMs features-Number of Cores : 0.2318
# LLMs features-Number of Threads : 0.0051
# LLMs features-Level 3 Cache : 0.2753
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4479
# LLMs features-Maximum Turbo Boost Frequency : 0.0382
# LLMs features-Number of Cores : 0.2321
# LLMs features-Number of Threads : 0.0063
# LLMs features-Level 3 Cache : 0.2755
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4470
# LLMs features-Maximum Turbo Boost Frequency : 0.0384
# LLMs features-Number of Cores : 0.2320
# LLMs features-Number of Threads : 0.0065
# LLMs features-Level 3 Cache : 0.2760
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4459
# LLMs features-Maximum Turbo Boost Frequency : 0.0379
# LLMs features-Number of Cores : 0.2324
# LLMs features-Number of Threads : 0.0072
# LLMs features-Level 3 Cache : 0.2766
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4451
# LLMs features-Maximum Turbo Boost Frequency : 0.0376
# LLMs features-Number of Cores : 0.2325
# LLMs features-Number of Threads : 0.0078
# LLMs features-Level 3 Cache : 0.2771
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4441
# LLMs features-Maximum Turbo Boost Frequency : 0.0386
# LLMs features-Number of Cores : 0.2313
# LLMs features-Number of Threads : 0.0080
# LLMs features-Level 3 Cache : 0.2781
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4433
# LLMs features-Maximum Turbo Boost Frequency : 0.0392
# LLMs features-Number of Cores : 0.2304
# LLMs features-Number of Threads : 0.0082
# LLMs features-Level 3 Cache : 0.2789
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4426
# LLMs features-Maximum Turbo Boost Frequency : 0.0398
# LLMs features-Number of Cores : 0.2294
# LLMs features-Number of Threads : 0.0083
# LLMs features-Level 3 Cache : 0.2797
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4416
# LLMs features-Maximum Turbo Boost Frequency : 0.0394
# LLMs features-Number of Cores : 0.2297
# LLMs features-Number of Threads : 0.0090
# LLMs features-Level 3 Cache : 0.2803
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4408
# LLMs features-Maximum Turbo Boost Frequency : 0.0393
# LLMs features-Number of Cores : 0.2296
# LLMs features-Number of Threads : 0.0095
# LLMs features-Level 3 Cache : 0.2808
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4399
# LLMs features-Maximum Turbo Boost Frequency : 0.0403
# LLMs features-Number of Cores : 0.2284
# LLMs features-Number of Threads : 0.0096
# LLMs features-Level 3 Cache : 0.2817
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4392
# LLMs features-Maximum Turbo Boost Frequency : 0.0408
# LLMs features-Number of Cores : 0.2277
# LLMs features-Number of Threads : 0.0098
# LLMs features-Level 3 Cache : 0.2825
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4385
# LLMs features-Maximum Turbo Boost Frequency : 0.0411
# LLMs features-Number of Cores : 0.2273
# LLMs features-Number of Threads : 0.0100
# LLMs features-Level 3 Cache : 0.2830
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4378
# LLMs features-Maximum Turbo Boost Frequency : 0.0413
# LLMs features-Number of Cores : 0.2271
# LLMs features-Number of Threads : 0.0102
# LLMs features-Level 3 Cache : 0.2836
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4370
# LLMs features-Maximum Turbo Boost Frequency : 0.0412
# LLMs features-Number of Cores : 0.2269
# LLMs features-Number of Threads : 0.0107
# LLMs features-Level 3 Cache : 0.2841
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4361
# LLMs features-Maximum Turbo Boost Frequency : 0.0410
# LLMs features-Number of Cores : 0.2274
# LLMs features-Number of Threads : 0.0114
# LLMs features-Level 3 Cache : 0.2843
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4353
# LLMs features-Maximum Turbo Boost Frequency : 0.0409
# LLMs features-Number of Cores : 0.2271
# LLMs features-Number of Threads : 0.0118
# LLMs features-Level 3 Cache : 0.2848
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4345
# LLMs features-Maximum Turbo Boost Frequency : 0.0411
# LLMs features-Number of Cores : 0.2270
# LLMs features-Number of Threads : 0.0121
# LLMs features-Level 3 Cache : 0.2853
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4338
# LLMs features-Maximum Turbo Boost Frequency : 0.0414
# LLMs features-Number of Cores : 0.2268
# LLMs features-Number of Threads : 0.0123
# LLMs features-Level 3 Cache : 0.2857
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4331
# LLMs features-Maximum Turbo Boost Frequency : 0.0416
# LLMs features-Number of Cores : 0.2265
# LLMs features-Number of Threads : 0.0125
# LLMs features-Level 3 Cache : 0.2863
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4320
# LLMs features-Maximum Turbo Boost Frequency : 0.0409
# LLMs features-Number of Cores : 0.2271
# LLMs features-Number of Threads : 0.0136
# LLMs features-Level 3 Cache : 0.2864
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4312
# LLMs features-Maximum Turbo Boost Frequency : 0.0419
# LLMs features-Number of Cores : 0.2258
# LLMs features-Number of Threads : 0.0137
# LLMs features-Level 3 Cache : 0.2874
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4304
# LLMs features-Maximum Turbo Boost Frequency : 0.0420
# LLMs features-Number of Cores : 0.2258
# LLMs features-Number of Threads : 0.0140
# LLMs features-Level 3 Cache : 0.2878
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4305
# LLMs features-Maximum Turbo Boost Frequency : 0.0422
# LLMs features-Number of Cores : 0.2258
# LLMs features-Number of Threads : 0.0138
# LLMs features-Level 3 Cache : 0.2877
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4299
# LLMs features-Maximum Turbo Boost Frequency : 0.0428
# LLMs features-Number of Cores : 0.2250
# LLMs features-Number of Threads : 0.0140
# LLMs features-Level 3 Cache : 0.2884
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4289
# LLMs features-Maximum Turbo Boost Frequency : 0.0449
# LLMs features-Number of Cores : 0.2229
# LLMs features-Number of Threads : 0.0136
# LLMs features-Level 3 Cache : 0.2897
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4283
# LLMs features-Maximum Turbo Boost Frequency : 0.0452
# LLMs features-Number of Cores : 0.2225
# LLMs features-Number of Threads : 0.0138
# LLMs features-Level 3 Cache : 0.2902
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4275
# LLMs features-Maximum Turbo Boost Frequency : 0.0461
# LLMs features-Number of Cores : 0.2213
# LLMs features-Number of Threads : 0.0140
# LLMs features-Level 3 Cache : 0.2911
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4276
# LLMs features-Maximum Turbo Boost Frequency : 0.0463
# LLMs features-Number of Cores : 0.2213
# LLMs features-Number of Threads : 0.0138
# LLMs features-Level 3 Cache : 0.2910
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4270
# LLMs features-Maximum Turbo Boost Frequency : 0.0467
# LLMs features-Number of Cores : 0.2207
# LLMs features-Number of Threads : 0.0140
# LLMs features-Level 3 Cache : 0.2917
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4263
# LLMs features-Maximum Turbo Boost Frequency : 0.0466
# LLMs features-Number of Cores : 0.2205
# LLMs features-Number of Threads : 0.0144
# LLMs features-Level 3 Cache : 0.2922
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4263
# LLMs features-Maximum Turbo Boost Frequency : 0.0468
# LLMs features-Number of Cores : 0.2205
# LLMs features-Number of Threads : 0.0143
# LLMs features-Level 3 Cache : 0.2921
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4255
# LLMs features-Maximum Turbo Boost Frequency : 0.0465
# LLMs features-Number of Cores : 0.2206
# LLMs features-Number of Threads : 0.0148
# LLMs features-Level 3 Cache : 0.2925
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4248
# LLMs features-Maximum Turbo Boost Frequency : 0.0462
# LLMs features-Number of Cores : 0.2207
# LLMs features-Number of Threads : 0.0153
# LLMs features-Level 3 Cache : 0.2930
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4241
# LLMs features-Maximum Turbo Boost Frequency : 0.0469
# LLMs features-Number of Cores : 0.2199
# LLMs features-Number of Threads : 0.0155
# LLMs features-Level 3 Cache : 0.2937
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4235
# LLMs features-Maximum Turbo Boost Frequency : 0.0477
# LLMs features-Number of Cores : 0.2189
# LLMs features-Number of Threads : 0.0155
# LLMs features-Level 3 Cache : 0.2943
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4228
# LLMs features-Maximum Turbo Boost Frequency : 0.0477
# LLMs features-Number of Cores : 0.2189
# LLMs features-Number of Threads : 0.0158
# LLMs features-Level 3 Cache : 0.2947
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4222
# LLMs features-Maximum Turbo Boost Frequency : 0.0477
# LLMs features-Number of Cores : 0.2187
# LLMs features-Number of Threads : 0.0163
# LLMs features-Level 3 Cache : 0.2952
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4216
# LLMs features-Maximum Turbo Boost Frequency : 0.0484
# LLMs features-Number of Cores : 0.2178
# LLMs features-Number of Threads : 0.0163
# LLMs features-Level 3 Cache : 0.2959
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4207
# LLMs features-Maximum Turbo Boost Frequency : 0.0480
# LLMs features-Number of Cores : 0.2180
# LLMs features-Number of Threads : 0.0169
# LLMs features-Level 3 Cache : 0.2963
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4202
# LLMs features-Maximum Turbo Boost Frequency : 0.0484
# LLMs features-Number of Cores : 0.2175
# LLMs features-Number of Threads : 0.0170
# LLMs features-Level 3 Cache : 0.2969
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4196
# LLMs features-Maximum Turbo Boost Frequency : 0.0484
# LLMs features-Number of Cores : 0.2173
# LLMs features-Number of Threads : 0.0174
# LLMs features-Level 3 Cache : 0.2974
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4187
# LLMs features-Maximum Turbo Boost Frequency : 0.0480
# LLMs features-Number of Cores : 0.2176
# LLMs features-Number of Threads : 0.0179
# LLMs features-Level 3 Cache : 0.2978
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4181
# LLMs features-Maximum Turbo Boost Frequency : 0.0485
# LLMs features-Number of Cores : 0.2169
# LLMs features-Number of Threads : 0.0181
# LLMs features-Level 3 Cache : 0.2984
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4173
# LLMs features-Maximum Turbo Boost Frequency : 0.0482
# LLMs features-Number of Cores : 0.2173
# LLMs features-Number of Threads : 0.0186
# LLMs features-Level 3 Cache : 0.2985
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4161
# LLMs features-Maximum Turbo Boost Frequency : 0.0479
# LLMs features-Number of Cores : 0.2176
# LLMs features-Number of Threads : 0.0196
# LLMs features-Level 3 Cache : 0.2987
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4153
# LLMs features-Maximum Turbo Boost Frequency : 0.0497
# LLMs features-Number of Cores : 0.2158
# LLMs features-Number of Threads : 0.0193
# LLMs features-Level 3 Cache : 0.3000
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4148
# LLMs features-Maximum Turbo Boost Frequency : 0.0502
# LLMs features-Number of Cores : 0.2151
# LLMs features-Number of Threads : 0.0194
# LLMs features-Level 3 Cache : 0.3006
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4142
# LLMs features-Maximum Turbo Boost Frequency : 0.0504
# LLMs features-Number of Cores : 0.2147
# LLMs features-Number of Threads : 0.0195
# LLMs features-Level 3 Cache : 0.3011
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4137
# LLMs features-Maximum Turbo Boost Frequency : 0.0506
# LLMs features-Number of Cores : 0.2145
# LLMs features-Number of Threads : 0.0197
# LLMs features-Level 3 Cache : 0.3015
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4132
# LLMs features-Maximum Turbo Boost Frequency : 0.0508
# LLMs features-Number of Cores : 0.2142
# LLMs features-Number of Threads : 0.0198
# LLMs features-Level 3 Cache : 0.3020
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4127
# LLMs features-Maximum Turbo Boost Frequency : 0.0511
# LLMs features-Number of Cores : 0.2139
# LLMs features-Number of Threads : 0.0200
# LLMs features-Level 3 Cache : 0.3024
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4119
# LLMs features-Maximum Turbo Boost Frequency : 0.0508
# LLMs features-Number of Cores : 0.2141
# LLMs features-Number of Threads : 0.0204
# LLMs features-Level 3 Cache : 0.3029
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4110
# LLMs features-Maximum Turbo Boost Frequency : 0.0504
# LLMs features-Number of Cores : 0.2144
# LLMs features-Number of Threads : 0.0209
# LLMs features-Level 3 Cache : 0.3033
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4111
# LLMs features-Maximum Turbo Boost Frequency : 0.0506
# LLMs features-Number of Cores : 0.2144
# LLMs features-Number of Threads : 0.0208
# LLMs features-Level 3 Cache : 0.3032
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4104
# LLMs features-Maximum Turbo Boost Frequency : 0.0503
# LLMs features-Number of Cores : 0.2144
# LLMs features-Number of Threads : 0.0213
# LLMs features-Level 3 Cache : 0.3036
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4099
# LLMs features-Maximum Turbo Boost Frequency : 0.0505
# LLMs features-Number of Cores : 0.2141
# LLMs features-Number of Threads : 0.0214
# LLMs features-Level 3 Cache : 0.3040
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4095
# LLMs features-Maximum Turbo Boost Frequency : 0.0510
# LLMs features-Number of Cores : 0.2135
# LLMs features-Number of Threads : 0.0215
# LLMs features-Level 3 Cache : 0.3046
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4090
# LLMs features-Maximum Turbo Boost Frequency : 0.0513
# LLMs features-Number of Cores : 0.2130
# LLMs features-Number of Threads : 0.0216
# LLMs features-Level 3 Cache : 0.3050
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4085
# LLMs features-Maximum Turbo Boost Frequency : 0.0525
# LLMs features-Number of Cores : 0.2116
# LLMs features-Number of Threads : 0.0214
# LLMs features-Level 3 Cache : 0.3060
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4079
# LLMs features-Maximum Turbo Boost Frequency : 0.0525
# LLMs features-Number of Cores : 0.2114
# LLMs features-Number of Threads : 0.0218
# LLMs features-Level 3 Cache : 0.3064
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4071
# LLMs features-Maximum Turbo Boost Frequency : 0.0521
# LLMs features-Number of Cores : 0.2117
# LLMs features-Number of Threads : 0.0223
# LLMs features-Level 3 Cache : 0.3068
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4065
# LLMs features-Maximum Turbo Boost Frequency : 0.0541
# LLMs features-Number of Cores : 0.2099
# LLMs features-Number of Threads : 0.0217
# LLMs features-Level 3 Cache : 0.3078
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4061
# LLMs features-Maximum Turbo Boost Frequency : 0.0544
# LLMs features-Number of Cores : 0.2095
# LLMs features-Number of Threads : 0.0218
# LLMs features-Level 3 Cache : 0.3083
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4056
# LLMs features-Maximum Turbo Boost Frequency : 0.0547
# LLMs features-Number of Cores : 0.2091
# LLMs features-Number of Threads : 0.0219
# LLMs features-Level 3 Cache : 0.3087
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4050
# LLMs features-Maximum Turbo Boost Frequency : 0.0544
# LLMs features-Number of Cores : 0.2092
# LLMs features-Number of Threads : 0.0223
# LLMs features-Level 3 Cache : 0.3091
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4045
# LLMs features-Maximum Turbo Boost Frequency : 0.0546
# LLMs features-Number of Cores : 0.2090
# LLMs features-Number of Threads : 0.0225
# LLMs features-Level 3 Cache : 0.3095
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4033
# LLMs features-Maximum Turbo Boost Frequency : 0.0564
# LLMs features-Number of Cores : 0.2074
# LLMs features-Number of Threads : 0.0223
# LLMs features-Level 3 Cache : 0.3106
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4027
# LLMs features-Maximum Turbo Boost Frequency : 0.0563
# LLMs features-Number of Cores : 0.2072
# LLMs features-Number of Threads : 0.0227
# LLMs features-Level 3 Cache : 0.3110
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4023
# LLMs features-Maximum Turbo Boost Frequency : 0.0565
# LLMs features-Number of Cores : 0.2069
# LLMs features-Number of Threads : 0.0228
# LLMs features-Level 3 Cache : 0.3114
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4018
# LLMs features-Maximum Turbo Boost Frequency : 0.0565
# LLMs features-Number of Cores : 0.2070
# LLMs features-Number of Threads : 0.0230
# LLMs features-Level 3 Cache : 0.3116
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4013
# LLMs features-Maximum Turbo Boost Frequency : 0.0572
# LLMs features-Number of Cores : 0.2063
# LLMs features-Number of Threads : 0.0231
# LLMs features-Level 3 Cache : 0.3122
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4008
# LLMs features-Maximum Turbo Boost Frequency : 0.0579
# LLMs features-Number of Cores : 0.2053
# LLMs features-Number of Threads : 0.0231
# LLMs features-Level 3 Cache : 0.3128
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.4004
# LLMs features-Maximum Turbo Boost Frequency : 0.0595
# LLMs features-Number of Cores : 0.2036
# LLMs features-Number of Threads : 0.0227
# LLMs features-Level 3 Cache : 0.3138
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3999
# LLMs features-Maximum Turbo Boost Frequency : 0.0596
# LLMs features-Number of Cores : 0.2036
# LLMs features-Number of Threads : 0.0228
# LLMs features-Level 3 Cache : 0.3140
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3995
# LLMs features-Maximum Turbo Boost Frequency : 0.0599
# LLMs features-Number of Cores : 0.2032
# LLMs features-Number of Threads : 0.0229
# LLMs features-Level 3 Cache : 0.3144
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3992
# LLMs features-Maximum Turbo Boost Frequency : 0.0603
# LLMs features-Number of Cores : 0.2027
# LLMs features-Number of Threads : 0.0230
# LLMs features-Level 3 Cache : 0.3149
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3985
# LLMs features-Maximum Turbo Boost Frequency : 0.0600
# LLMs features-Number of Cores : 0.2028
# LLMs features-Number of Threads : 0.0234
# LLMs features-Level 3 Cache : 0.3152
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3975
# LLMs features-Maximum Turbo Boost Frequency : 0.0597
# LLMs features-Number of Cores : 0.2031
# LLMs features-Number of Threads : 0.0243
# LLMs features-Level 3 Cache : 0.3154
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3970
# LLMs features-Maximum Turbo Boost Frequency : 0.0596
# LLMs features-Number of Cores : 0.2029
# LLMs features-Number of Threads : 0.0246
# LLMs features-Level 3 Cache : 0.3158
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3966
# LLMs features-Maximum Turbo Boost Frequency : 0.0598
# LLMs features-Number of Cores : 0.2027
# LLMs features-Number of Threads : 0.0247
# LLMs features-Level 3 Cache : 0.3161
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3959
# LLMs features-Maximum Turbo Boost Frequency : 0.0596
# LLMs features-Number of Cores : 0.2031
# LLMs features-Number of Threads : 0.0252
# LLMs features-Level 3 Cache : 0.3162
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3948
# LLMs features-Maximum Turbo Boost Frequency : 0.0612
# LLMs features-Number of Cores : 0.2016
# LLMs features-Number of Threads : 0.0251
# LLMs features-Level 3 Cache : 0.3173
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3940
# LLMs features-Maximum Turbo Boost Frequency : 0.0608
# LLMs features-Number of Cores : 0.2020
# LLMs features-Number of Threads : 0.0256
# LLMs features-Level 3 Cache : 0.3176
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3935
# LLMs features-Maximum Turbo Boost Frequency : 0.0606
# LLMs features-Number of Cores : 0.2020
# LLMs features-Number of Threads : 0.0259
# LLMs features-Level 3 Cache : 0.3180
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3932
# LLMs features-Maximum Turbo Boost Frequency : 0.0611
# LLMs features-Number of Cores : 0.2014
# LLMs features-Number of Threads : 0.0260
# LLMs features-Level 3 Cache : 0.3184
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3925
# LLMs features-Maximum Turbo Boost Frequency : 0.0609
# LLMs features-Number of Cores : 0.2018
# LLMs features-Number of Threads : 0.0264
# LLMs features-Level 3 Cache : 0.3184
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3919
# LLMs features-Maximum Turbo Boost Frequency : 0.0607
# LLMs features-Number of Cores : 0.2018
# LLMs features-Number of Threads : 0.0268
# LLMs features-Level 3 Cache : 0.3188
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3916
# LLMs features-Maximum Turbo Boost Frequency : 0.0609
# LLMs features-Number of Cores : 0.2015
# LLMs features-Number of Threads : 0.0269
# LLMs features-Level 3 Cache : 0.3192
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3910
# LLMs features-Maximum Turbo Boost Frequency : 0.0606
# LLMs features-Number of Cores : 0.2016
# LLMs features-Number of Threads : 0.0273
# LLMs features-Level 3 Cache : 0.3195
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3906
# LLMs features-Maximum Turbo Boost Frequency : 0.0608
# LLMs features-Number of Cores : 0.2014
# LLMs features-Number of Threads : 0.0274
# LLMs features-Level 3 Cache : 0.3198
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3901
# LLMs features-Maximum Turbo Boost Frequency : 0.0609
# LLMs features-Number of Cores : 0.2015
# LLMs features-Number of Threads : 0.0275
# LLMs features-Level 3 Cache : 0.3200
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3896
# LLMs features-Maximum Turbo Boost Frequency : 0.0607
# LLMs features-Number of Cores : 0.2014
# LLMs features-Number of Threads : 0.0279
# LLMs features-Level 3 Cache : 0.3204
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3892
# LLMs features-Maximum Turbo Boost Frequency : 0.0614
# LLMs features-Number of Cores : 0.2005
# LLMs features-Number of Threads : 0.0279
# LLMs features-Level 3 Cache : 0.3209
# Overall importance of each element in aug_data to the model:
# LLMs features-CPU Clock Frequency : 0.3889
# LLMs features-Maximum Turbo Boost Frequency : 0.0616
# LLMs features-Number of Cores : 0.2002
# LLMs features-Number of Threads : 0.0280
# LLMs features-Level 3 Cache : 0.3213

# %%
all_device_importance
# Out:
# array([0.45456609, 0.03747935, 0.22867044, 0.02022622, 0.25905791])

# %%
for i in range(len(all_device_importance)):
    print(f"{all_device_importance[i] * 100:.2f}\%", end=' & ')
# Out:
# 45.46\% & 3.75\% & 22.87\% & 2.02\% & 25.91\% &

# %%
import random


def get_node_importance(model, sample_input):
    graph, features, values = sample_input
    features = features.reshape(1, -1).long()
    g, feats = graph, model.model.graph_encoder.dnn_embedding(features).reshape(features.shape[0] * 9, -1)
    attention_weights = []
    for i, (layer, norm, act) in enumerate(zip(model.model.graph_encoder.layers, model.model.graph_encoder.norms, model.model.graph_encoder.acts)):
        # 获取 GAT 的注意力权重
        feats, attn = layer(g, feats, get_attention=True)
        feats = feats.mean(dim=1)  # 聚合多个头的输出
        feats = norm(feats)
        feats = act(feats)
        attention_weights.append(attn)
    batch_sizes = torch.as_tensor(g.batch_num_nodes()).to(model.model.args.device)  # 每个图的节点数
    first_nodes_idx = torch.cumsum(torch.cat((torch.tensor([0]).to(model.model.args.device), batch_sizes[:-1])), dim=0)  # 使用torch.cat来连接Tensor
    first_node_features = feats[first_nodes_idx]
    return first_node_features, attention_weights


def aggregate_node_attention(model, sample_input, graph, global_node_attention):
    # 获取图中的节点数和边数
    num_nodes = graph.number_of_nodes()
    num_edges = graph.number_of_edges()

    # 假设 global_node_attention 的形状是 [num_edges, num_heads, 1]
    mean_attention = global_node_attention.mean(dim=1).squeeze(-1)  # [num_edges]
    
    # print("Mean attention per edge:", mean_attention)
    
    # 初始化每个节点的注意力权重为零
    node_importance = torch.zeros(num_nodes, device=mean_attention.device)
    
    # 遍历每条边，将注意力权重聚合到对应的节点上
    for edge_idx in range(num_edges):
        src, dst = graph.find_edges(edge_idx)  # 获取边的起始节点和目标节点
        if dst == 0:
            # 累加目标节点的注意力权重
            node_importance[src] += mean_attention[edge_idx]
            # print(f"Edge {edge_idx:2d}: src={src}, dst={dst}, Attention={mean_attention[edge_idx]:.4f}, accumulated importance={node_importance[src]}")
    
    # 最后可以对 node_importance 进行归一化处理，使其值在合理范围内
    node_importance = node_importance / node_importance.sum()
    
    print("Node importance to the global node:\n", node_importance.detach().cpu().numpy())

    # 获取 graph_importance
    graph_importance, _ = get_embeds_importance(model, sample_input)
    each_device_node_importance = graph_importance * node_importance
    each_device_node_importance = each_device_node_importance.detach().numpy()
    _, key, values = sample_input
    print(key)
    print("Overall importance of each element in graph to the Global Node:")
    for i in range(len(key)):
        print(f"Key-{key[i]}-{op_name[key[i]]}: {each_device_node_importance[i]:.4f}")
    return node_importance


# 使用函数计算每个节点对全局节点的重要性
idx = random.randint(0, len(datamodule.train_loader.dataset))
sample_input = datamodule.train_loader.dataset[idx]
graph, features, values = sample_input
first_node_features, attention_weights = get_node_importance(model, sample_input = datamodule.train_loader.dataset[idx])
node_importance = aggregate_node_attention(model, sample_input, graph, attention_weights[-1]).detach().cpu().numpy()
# Out:
# Node importance to the global node:
#  [0.2237378  0.20893955 0.         0.18403508 0.         0.19714415
#  0.         0.         0.18614344]
# tensor([5, 3, 0, 2, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1229
# Key-3-input: 0.1148
# Key-0-con1: 0.0000
# Key-2-max3: 0.1011
# Key-0-con1: 0.0000
# Key-1-con3: 0.1083
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1022

# %%
all_node_importance = np.zeros(9)
idx = random.randint(0, len(datamodule.train_loader.dataset))
for i in range(len(datamodule.train_loader.dataset)):
    sample_input = datamodule.train_loader.dataset[i]
    graph, features, values = sample_input
    first_node_features, attention_weights = get_node_importance(model, sample_input = datamodule.train_loader.dataset[i])
    node_importance = aggregate_node_attention(model, sample_input, graph, attention_weights[-1]).detach().cpu().numpy()
    break
# Out:
# Node importance to the global node:
#  [0.13280469 0.14259605 0.23872896 0.         0.         0.12645777
#  0.20422941 0.         0.15518314]
# tensor([5, 3, 0, 0, 0, 1, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0793
# Key-3-input: 0.0852
# Key-0-con1: 0.1426
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0755
# Key-1-con3: 0.1220
# Key-0-con1: 0.0000
# Key-4-output: 0.0927

# %%
import numpy as np
import random

# 初始化存储重要性累积和出现次数的字典
all_node_importance = {i: 0 for i in range(9)}
key_counts = {i: 0 for i in range(9)}

idx = random.randint(0, len(datamodule.train_loader.dataset))
for i in range(len(datamodule.train_loader.dataset)):
    sample_input = datamodule.train_loader.dataset[i]
    graph, features, values = sample_input
    first_node_features, attention_weights = get_node_importance(model, sample_input = datamodule.train_loader.dataset[i])
    node_importance = aggregate_node_attention(model, sample_input, graph, attention_weights[-1]).detach().cpu().numpy()
    
    for key in features.numpy():
        if node_importance[key] == 0:
            continue
        all_node_importance[key] += node_importance[key]
        key_counts[key] += 1  # 统计每个 key 出现的次数
    
# 计算每个 key 的平均值
average_importance = {key: all_node_importance[key] / key_counts[key] for key in all_node_importance if key_counts[key] > 0}

# 打印结果
print("Node importance to the global node:\n", node_importance)
print("tensor:", features)
print("Overall average importance of each element in graph to the Global Node:")
for key, avg_value in average_importance.items():
    print(f"Key-{key}-{op_name[key]}: {avg_value:.4f}")
# Out:
# Node importance to the global node:
#  [0.17458987 0.13331988 0.1754015  0.         0.         0.10634027
#  0.20527203 0.         0.20507644]
# tensor([5, 3, 0, 0, 0, 1, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1040
# Key-3-input: 0.0794
# Key-0-con1: 0.1045
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0634
# Key-1-con3: 0.1223
# Key-0-con1: 0.0000
# Key-4-output: 0.1222
# Node importance to the global node:
#  [0.1623798  0.14269248 0.17175214 0.         0.         0.18581527
#  0.17338851 0.         0.16397187]
# tensor([5, 3, 2, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0895
# Key-3-input: 0.0786
# Key-2-max3: 0.0946
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1024
# Key-0-con1: 0.0955
# Key-0-con1: 0.0000
# Key-4-output: 0.0903
# Node importance to the global node:
#  [0.16303375 0.15230024 0.15737665 0.18693058 0.         0.17008786
#  0.         0.         0.17027092]
# tensor([5, 3, 1, 1, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0932
# Key-3-input: 0.0871
# Key-1-con3: 0.0900
# Key-1-con3: 0.1069
# Key-0-con1: 0.0000
# Key-1-con3: 0.0972
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.0973
# Node importance to the global node:
#  [0.2425775  0.25048608 0.         0.         0.         0.25960323
#  0.         0.         0.24733327]
# tensor([5, 3, 0, 0, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1274
# Key-3-input: 0.1316
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1364
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1299
# Node importance to the global node:
#  [0.24532637 0.23418064 0.         0.         0.         0.272105
#  0.         0.         0.24838795]
# tensor([5, 3, 0, 0, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1292
# Key-3-input: 0.1233
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1433
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1308
# Node importance to the global node:
#  [0.17269652 0.12796493 0.         0.16156964 0.         0.09909439
#  0.         0.22906907 0.2096055 ]
# tensor([5, 3, 0, 0, 0, 1, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0986
# Key-3-input: 0.0731
# Key-0-con1: 0.0000
# Key-0-con1: 0.0923
# Key-0-con1: 0.0000
# Key-1-con3: 0.0566
# Key-0-con1: 0.0000
# Key-1-con3: 0.1308
# Key-4-output: 0.1197
# Node importance to the global node:
#  [0.23634046 0.24304897 0.         0.         0.         0.2756717
#  0.         0.         0.24493887]
# tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1235
# Key-3-input: 0.1270
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1440
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1280
# Node importance to the global node:
#  [0.15055484 0.10699912 0.1630086  0.09769558 0.15881659 0.
#  0.06619596 0.1561899  0.10053943]
# tensor([5, 3, 0, 1, 1, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0863
# Key-3-input: 0.0613
# Key-0-con1: 0.0934
# Key-1-con3: 0.0560
# Key-1-con3: 0.0910
# Key-0-con1: 0.0000
# Key-0-con1: 0.0379
# Key-0-con1: 0.0895
# Key-4-output: 0.0576
# Node importance to the global node:
#  [0.15638383 0.12629707 0.08987348 0.14118072 0.20341463 0.
#  0.         0.11186996 0.17098026]
# tensor([5, 3, 1, 0, 2, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0815
# Key-3-input: 0.0659
# Key-1-con3: 0.0469
# Key-0-con1: 0.0736
# Key-2-max3: 0.1061
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0583
# Key-4-output: 0.0892
# Node importance to the global node:
#  [0.19853881 0.19453125 0.20351188 0.         0.         0.
#  0.198867   0.         0.20455104]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1034
# Key-3-input: 0.1013
# Key-0-con1: 0.1060
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1036
# Key-0-con1: 0.0000
# Key-4-output: 0.1065
# Node importance to the global node:
#  [0.322342   0.3211083  0.         0.         0.         0.
#  0.         0.         0.35654968]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1657
# Key-3-input: 0.1651
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1833
# Node importance to the global node:
#  [0.1387167  0.15474585 0.         0.1259658  0.13161083 0.14321035
#  0.14329407 0.         0.16245648]
# tensor([5, 3, 0, 2, 1, 2, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0795
# Key-3-input: 0.0887
# Key-0-con1: 0.0000
# Key-2-max3: 0.0722
# Key-1-con3: 0.0754
# Key-2-max3: 0.0821
# Key-2-max3: 0.0821
# Key-0-con1: 0.0000
# Key-4-output: 0.0931
# Node importance to the global node:
#  [0.1474739  0.16768005 0.11317234 0.         0.17784867 0.07506488
#  0.11158113 0.07793193 0.1292471 ]
# tensor([5, 3, 0, 0, 1, 2, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0845
# Key-3-input: 0.0961
# Key-0-con1: 0.0648
# Key-0-con1: 0.0000
# Key-1-con3: 0.1019
# Key-2-max3: 0.0430
# Key-2-max3: 0.0639
# Key-0-con1: 0.0446
# Key-4-output: 0.0740
# Node importance to the global node:
#  [0.16977523 0.14243528 0.13966954 0.         0.16041607 0.10761955
#  0.11265524 0.11122364 0.0562055 ]
# tensor([5, 3, 2, 0, 1, 0, 1, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0861
# Key-3-input: 0.0722
# Key-2-max3: 0.0708
# Key-0-con1: 0.0000
# Key-1-con3: 0.0813
# Key-0-con1: 0.0545
# Key-1-con3: 0.0571
# Key-1-con3: 0.0564
# Key-4-output: 0.0285
# Node importance to the global node:
#  [0.14107555 0.12587188 0.16451226 0.12255284 0.12363233 0.08551262
#  0.13534683 0.         0.10149562]
# tensor([5, 3, 2, 0, 2, 1, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0841
# Key-3-input: 0.0751
# Key-2-max3: 0.0981
# Key-0-con1: 0.0731
# Key-2-max3: 0.0737
# Key-1-con3: 0.0510
# Key-1-con3: 0.0807
# Key-0-con1: 0.0000
# Key-4-output: 0.0605
# Node importance to the global node:
#  [0.19118896 0.17001005 0.         0.26954758 0.         0.
#  0.         0.1857445  0.18350898]
# tensor([5, 3, 0, 1, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1093
# Key-3-input: 0.0972
# Key-0-con1: 0.0000
# Key-1-con3: 0.1541
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1062
# Key-4-output: 0.1049
# Node importance to the global node:
#  [0.2390098  0.27165496 0.25175762 0.         0.         0.
#  0.         0.         0.23757766]
# tensor([5, 3, 2, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1254
# Key-3-input: 0.1426
# Key-2-max3: 0.1321
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1247
# Node importance to the global node:
#  [0.18899748 0.19445568 0.1919311  0.         0.15093236 0.
#  0.         0.10574026 0.16794306]
# tensor([5, 3, 2, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1081
# Key-3-input: 0.1113
# Key-2-max3: 0.1098
# Key-0-con1: 0.0000
# Key-0-con1: 0.0864
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0605
# Key-4-output: 0.0961
# Node importance to the global node:
#  [0.11409587 0.14815994 0.15854171 0.12001704 0.         0.
#  0.16265993 0.15338884 0.14313667]
# tensor([5, 3, 2, 1, 0, 0, 1, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0682
# Key-3-input: 0.0885
# Key-2-max3: 0.0947
# Key-1-con3: 0.0717
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0972
# Key-2-max3: 0.0916
# Key-4-output: 0.0855
# Node importance to the global node:
#  [0.23784849 0.19131902 0.         0.         0.         0.21932167
#  0.15421076 0.         0.19730009]
# tensor([5, 3, 0, 0, 0, 1, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1303
# Key-3-input: 0.1048
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1201
# Key-2-max3: 0.0845
# Key-0-con1: 0.0000
# Key-4-output: 0.1081
# Node importance to the global node:
#  [0.12478822 0.15158975 0.13436505 0.09016748 0.10074314 0.06419355
#  0.17155956 0.08458763 0.07800564]
# tensor([5, 3, 2, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0713
# Key-3-input: 0.0867
# Key-2-max3: 0.0768
# Key-0-con1: 0.0516
# Key-0-con1: 0.0576
# Key-0-con1: 0.0367
# Key-0-con1: 0.0981
# Key-0-con1: 0.0484
# Key-4-output: 0.0446
# Node importance to the global node:
#  [0.18670398 0.13184135 0.18147974 0.11091347 0.17545947 0.
#  0.         0.15215103 0.06145097]
# tensor([5, 3, 0, 1, 1, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1099
# Key-3-input: 0.0776
# Key-0-con1: 0.1068
# Key-1-con3: 0.0653
# Key-1-con3: 0.1033
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0896
# Key-4-output: 0.0362
# Node importance to the global node:
#  [0.11515611 0.11577159 0.1605738  0.         0.17261423 0.07227014
#  0.09967028 0.1536443  0.11029953]
# tensor([5, 3, 2, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0658
# Key-3-input: 0.0662
# Key-2-max3: 0.0918
# Key-0-con1: 0.0000
# Key-0-con1: 0.0986
# Key-1-con3: 0.0413
# Key-0-con1: 0.0570
# Key-0-con1: 0.0878
# Key-4-output: 0.0630
# Node importance to the global node:
#  [0.1920083  0.24436048 0.21134908 0.         0.         0.
#  0.17912155 0.         0.17316055]
# tensor([5, 3, 1, 0, 0, 0, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1099
# Key-3-input: 0.1399
# Key-1-con3: 0.1210
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1025
# Key-0-con1: 0.0000
# Key-4-output: 0.0991
# Node importance to the global node:
#  [0.1890054  0.17292649 0.         0.16666885 0.         0.19750535
#  0.         0.13662437 0.13726951]
# tensor([5, 3, 0, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1032
# Key-3-input: 0.0944
# Key-0-con1: 0.0000
# Key-2-max3: 0.0910
# Key-0-con1: 0.0000
# Key-0-con1: 0.1078
# Key-0-con1: 0.0000
# Key-0-con1: 0.0746
# Key-4-output: 0.0749
# Node importance to the global node:
#  [0.20576665 0.22638632 0.         0.18262394 0.         0.
#  0.         0.18528852 0.1999346 ]
# tensor([5, 3, 0, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1114
# Key-3-input: 0.1226
# Key-0-con1: 0.0000
# Key-2-max3: 0.0989
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1003
# Key-4-output: 0.1082
# Node importance to the global node:
#  [0.16774856 0.17268328 0.         0.175028   0.12649015 0.11755884
#  0.         0.13728416 0.10320696]
# tensor([5, 3, 0, 1, 1, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0996
# Key-3-input: 0.1026
# Key-0-con1: 0.0000
# Key-1-con3: 0.1040
# Key-1-con3: 0.0751
# Key-2-max3: 0.0698
# Key-0-con1: 0.0000
# Key-0-con1: 0.0815
# Key-4-output: 0.0613
# Node importance to the global node:
#  [0.2200394  0.19315101 0.         0.         0.         0.20233464
#  0.17473087 0.         0.20974405]
# tensor([5, 3, 0, 0, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1189
# Key-3-input: 0.1044
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1093
# Key-0-con1: 0.0944
# Key-0-con1: 0.0000
# Key-4-output: 0.1133
# Node importance to the global node:
#  [0.18062797 0.15932932 0.         0.1837667  0.         0.14554197
#  0.         0.17870341 0.15203063]
# tensor([5, 3, 0, 0, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0986
# Key-3-input: 0.0869
# Key-0-con1: 0.0000
# Key-0-con1: 0.1003
# Key-0-con1: 0.0000
# Key-0-con1: 0.0794
# Key-0-con1: 0.0000
# Key-1-con3: 0.0975
# Key-4-output: 0.0830
# Node importance to the global node:
#  [0.1789437  0.14923441 0.19157845 0.         0.15511483 0.
#  0.16003002 0.         0.16509862]
# tensor([5, 3, 1, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0978
# Key-3-input: 0.0816
# Key-1-con3: 0.1047
# Key-0-con1: 0.0000
# Key-0-con1: 0.0848
# Key-0-con1: 0.0000
# Key-0-con1: 0.0875
# Key-0-con1: 0.0000
# Key-4-output: 0.0902
# Node importance to the global node:
#  [0.1861266  0.19565846 0.         0.20658353 0.         0.
#  0.         0.20213048 0.20950092]
# tensor([5, 3, 0, 2, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1061
# Key-3-input: 0.1116
# Key-0-con1: 0.0000
# Key-2-max3: 0.1178
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1153
# Key-4-output: 0.1195
# Node importance to the global node:
#  [0.2116664  0.20349392 0.         0.19632064 0.         0.22389352
#  0.         0.         0.16462548]
# tensor([5, 3, 0, 2, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1159
# Key-3-input: 0.1114
# Key-0-con1: 0.0000
# Key-2-max3: 0.1075
# Key-0-con1: 0.0000
# Key-1-con3: 0.1226
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.0902
# Node importance to the global node:
#  [0.23572119 0.2547668  0.26285273 0.         0.         0.
#  0.         0.         0.2466593 ]
# tensor([5, 3, 1, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1224
# Key-3-input: 0.1323
# Key-1-con3: 0.1365
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1281
# Node importance to the global node:
#  [0.17582774 0.1693535  0.15118428 0.17021166 0.         0.
#  0.         0.19820938 0.13521354]
# tensor([5, 3, 2, 0, 0, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0955
# Key-3-input: 0.0920
# Key-2-max3: 0.0821
# Key-0-con1: 0.0924
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1076
# Key-4-output: 0.0734
# Node importance to the global node:
#  [0.20014432 0.22094253 0.         0.19688052 0.         0.
#  0.         0.19400132 0.18803135]
# tensor([5, 3, 0, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1085
# Key-3-input: 0.1198
# Key-0-con1: 0.0000
# Key-2-max3: 0.1067
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1052
# Key-4-output: 0.1019
# Node importance to the global node:
#  [0.1556797  0.15463558 0.15499672 0.1010157  0.         0.10210508
#  0.22889674 0.         0.10267048]
# tensor([5, 3, 0, 1, 0, 1, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0892
# Key-3-input: 0.0886
# Key-0-con1: 0.0888
# Key-1-con3: 0.0579
# Key-0-con1: 0.0000
# Key-1-con3: 0.0585
# Key-2-max3: 0.1312
# Key-0-con1: 0.0000
# Key-4-output: 0.0588
# Node importance to the global node:
#  [0.18877578 0.19781145 0.         0.19787997 0.         0.21229261
#  0.         0.         0.20324025]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0985
# Key-3-input: 0.1032
# Key-0-con1: 0.0000
# Key-0-con1: 0.1032
# Key-0-con1: 0.0000
# Key-0-con1: 0.1108
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1060
# Node importance to the global node:
#  [0.24985181 0.26558566 0.         0.         0.         0.
#  0.         0.24076086 0.2438016 ]
# tensor([5, 3, 0, 0, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1293
# Key-3-input: 0.1374
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1246
# Key-4-output: 0.1261
# Node importance to the global node:
#  [0.14506087 0.1811287  0.14445558 0.1407017  0.         0.12097184
#  0.         0.1386846  0.12899683]
# tensor([5, 3, 0, 0, 0, 2, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0794
# Key-3-input: 0.0991
# Key-0-con1: 0.0790
# Key-0-con1: 0.0770
# Key-0-con1: 0.0000
# Key-2-max3: 0.0662
# Key-0-con1: 0.0000
# Key-2-max3: 0.0759
# Key-4-output: 0.0706
# Node importance to the global node:
#  [0.24190865 0.21202254 0.         0.         0.1644768  0.
#  0.         0.18857557 0.19301642]
# tensor([5, 3, 0, 0, 2, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1376
# Key-3-input: 0.1206
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0936
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1073
# Key-4-output: 0.1098
# Node importance to the global node:
#  [0.17472075 0.22506283 0.         0.22876199 0.         0.
#  0.         0.19307503 0.17837943]
# tensor([5, 3, 0, 1, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0950
# Key-3-input: 0.1224
# Key-0-con1: 0.0000
# Key-1-con3: 0.1244
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1050
# Key-4-output: 0.0970
# Node importance to the global node:
#  [0.18335986 0.15036245 0.         0.16254161 0.         0.15361194
#  0.         0.18194494 0.16817921]
# tensor([5, 3, 0, 1, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1012
# Key-3-input: 0.0830
# Key-0-con1: 0.0000
# Key-1-con3: 0.0897
# Key-0-con1: 0.0000
# Key-2-max3: 0.0848
# Key-0-con1: 0.0000
# Key-0-con1: 0.1004
# Key-4-output: 0.0928
# Node importance to the global node:
#  [0.24720177 0.18644804 0.19969368 0.         0.         0.18078415
#  0.         0.         0.18587235]
# tensor([5, 3, 2, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1352
# Key-3-input: 0.1019
# Key-2-max3: 0.1092
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0988
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1016
# Node importance to the global node:
#  [0.2505731  0.24943024 0.         0.         0.         0.24691601
#  0.         0.         0.25308067]
# tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1305
# Key-3-input: 0.1299
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1286
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1318
# Node importance to the global node:
#  [0.24460189 0.24085872 0.         0.         0.         0.26232058
#  0.         0.         0.25221878]
# tensor([5, 3, 0, 0, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1295
# Key-3-input: 0.1276
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1389
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1336
# Node importance to the global node:
#  [0.17842263 0.15750822 0.         0.16536182 0.         0.15501128
#  0.         0.15416013 0.18953595]
# tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0961
# Key-3-input: 0.0849
# Key-0-con1: 0.0000
# Key-0-con1: 0.0891
# Key-0-con1: 0.0000
# Key-1-con3: 0.0835
# Key-0-con1: 0.0000
# Key-0-con1: 0.0831
# Key-4-output: 0.1021
# Node importance to the global node:
#  [0.15534997 0.09633087 0.12899785 0.         0.17987588 0.08387084
#  0.11480482 0.1689428  0.07182696]
# tensor([5, 3, 1, 0, 2, 2, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0914
# Key-3-input: 0.0567
# Key-1-con3: 0.0759
# Key-0-con1: 0.0000
# Key-2-max3: 0.1059
# Key-2-max3: 0.0494
# Key-1-con3: 0.0676
# Key-0-con1: 0.0994
# Key-4-output: 0.0423
# Node importance to the global node:
#  [0.11787377 0.20041892 0.12846248 0.09922567 0.22516586 0.07358247
#  0.         0.         0.15527071]
# tensor([5, 3, 2, 1, 1, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0703
# Key-3-input: 0.1196
# Key-2-max3: 0.0767
# Key-1-con3: 0.0592
# Key-1-con3: 0.1344
# Key-1-con3: 0.0439
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.0927
# Node importance to the global node:
#  [0.24150068 0.24859546 0.254095   0.         0.         0.
#  0.         0.         0.25580892]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1251
# Key-3-input: 0.1288
# Key-0-con1: 0.1317
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1326
# Node importance to the global node:
#  [0.13370503 0.13160652 0.13640566 0.         0.         0.120658
#  0.18372306 0.14831617 0.14558564]
# tensor([5, 3, 0, 0, 0, 2, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0731
# Key-3-input: 0.0720
# Key-0-con1: 0.0746
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0660
# Key-2-max3: 0.1005
# Key-0-con1: 0.0811
# Key-4-output: 0.0796
# Node importance to the global node:
#  [0.18134218 0.1671214  0.         0.18550579 0.         0.16242403
#  0.         0.15901414 0.14459248]
# tensor([5, 3, 0, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0991
# Key-3-input: 0.0913
# Key-0-con1: 0.0000
# Key-2-max3: 0.1013
# Key-0-con1: 0.0000
# Key-0-con1: 0.0887
# Key-0-con1: 0.0000
# Key-0-con1: 0.0869
# Key-4-output: 0.0790
# Node importance to the global node:
#  [0.13697174 0.13663772 0.14184691 0.11511932 0.09094384 0.
#  0.07615832 0.14277053 0.15955158]
# tensor([5, 3, 2, 2, 1, 0, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0816
# Key-3-input: 0.0814
# Key-2-max3: 0.0845
# Key-2-max3: 0.0686
# Key-1-con3: 0.0542
# Key-0-con1: 0.0000
# Key-2-max3: 0.0454
# Key-0-con1: 0.0851
# Key-4-output: 0.0951
# Node importance to the global node:
#  [0.15875831 0.14032    0.12690292 0.         0.         0.18870805
#  0.20457934 0.         0.1807314 ]
# tensor([5, 3, 1, 0, 0, 2, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0950
# Key-3-input: 0.0839
# Key-1-con3: 0.0759
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1129
# Key-1-con3: 0.1224
# Key-0-con1: 0.0000
# Key-4-output: 0.1081
# Node importance to the global node:
#  [0.12987484 0.123467   0.21722405 0.07780032 0.14614627 0.07378923
#  0.         0.13791658 0.09378171]
# tensor([5, 3, 1, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0744
# Key-3-input: 0.0707
# Key-1-con3: 0.1244
# Key-2-max3: 0.0446
# Key-0-con1: 0.0837
# Key-0-con1: 0.0423
# Key-0-con1: 0.0000
# Key-0-con1: 0.0790
# Key-4-output: 0.0537
# Node importance to the global node:
#  [0.112808   0.09568395 0.16710293 0.14778611 0.         0.11718401
#  0.12659076 0.08525183 0.1475925 ]
# tensor([5, 3, 1, 1, 0, 1, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0672
# Key-3-input: 0.0570
# Key-1-con3: 0.0996
# Key-1-con3: 0.0881
# Key-0-con1: 0.0000
# Key-1-con3: 0.0698
# Key-0-con1: 0.0754
# Key-1-con3: 0.0508
# Key-4-output: 0.0879
# Node importance to the global node:
#  [0.1747275  0.17053162 0.         0.26107615 0.         0.
#  0.         0.19362147 0.20004334]
# tensor([5, 3, 0, 2, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0997
# Key-3-input: 0.0973
# Key-0-con1: 0.0000
# Key-2-max3: 0.1490
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1105
# Key-4-output: 0.1142
# Node importance to the global node:
#  [0.28122312 0.24654576 0.         0.         0.         0.
#  0.2203361  0.         0.25189507]
# tensor([5, 3, 0, 0, 0, 0, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1484
# Key-3-input: 0.1301
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1163
# Key-0-con1: 0.0000
# Key-4-output: 0.1329
# Node importance to the global node:
#  [0.12364781 0.08227275 0.1412994  0.         0.12153796 0.06984493
#  0.07918322 0.15925054 0.22296338]
# tensor([5, 3, 0, 0, 0, 1, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0707
# Key-3-input: 0.0471
# Key-0-con1: 0.0808
# Key-0-con1: 0.0000
# Key-0-con1: 0.0695
# Key-1-con3: 0.0400
# Key-0-con1: 0.0453
# Key-2-max3: 0.0911
# Key-4-output: 0.1275
# Node importance to the global node:
#  [0.20187785 0.16586843 0.         0.         0.20535497 0.
#  0.22689186 0.         0.20000689]
# tensor([5, 3, 0, 0, 1, 0, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1103
# Key-3-input: 0.0906
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1122
# Key-0-con1: 0.0000
# Key-2-max3: 0.1240
# Key-0-con1: 0.0000
# Key-4-output: 0.1093
# Node importance to the global node:
#  [0.15191603 0.14822803 0.         0.13835186 0.15945746 0.11959286
#  0.13290067 0.         0.14955302]
# tensor([5, 3, 0, 2, 0, 0, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0837
# Key-3-input: 0.0816
# Key-0-con1: 0.0000
# Key-2-max3: 0.0762
# Key-0-con1: 0.0878
# Key-0-con1: 0.0659
# Key-1-con3: 0.0732
# Key-0-con1: 0.0000
# Key-4-output: 0.0824
# Node importance to the global node:
#  [0.1407356  0.11246938 0.19740313 0.0948249  0.17745686 0.0618347
#  0.         0.10569094 0.10958452]
# tensor([5, 3, 0, 0, 1, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0806
# Key-3-input: 0.0644
# Key-0-con1: 0.1131
# Key-0-con1: 0.0543
# Key-1-con3: 0.1017
# Key-0-con1: 0.0354
# Key-0-con1: 0.0000
# Key-0-con1: 0.0606
# Key-4-output: 0.0628
# Node importance to the global node:
#  [0.15095039 0.14706215 0.17666179 0.14399014 0.14112681 0.11779702
#  0.         0.         0.12241168]
# tensor([5, 3, 2, 2, 2, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0859
# Key-3-input: 0.0837
# Key-2-max3: 0.1005
# Key-2-max3: 0.0819
# Key-2-max3: 0.0803
# Key-2-max3: 0.0670
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.0697
# Node importance to the global node:
#  [0.19560671 0.13054493 0.17167838 0.         0.         0.13180073
#  0.1582107  0.         0.21215843]
# tensor([5, 3, 1, 0, 0, 0, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1170
# Key-3-input: 0.0781
# Key-1-con3: 0.1027
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0789
# Key-1-con3: 0.0947
# Key-0-con1: 0.0000
# Key-4-output: 0.1269
# Node importance to the global node:
#  [0.12367743 0.12505808 0.07021026 0.11335751 0.13246706 0.11012814
#  0.10803781 0.10657175 0.11049198]
# tensor([5, 3, 2, 2, 0, 2, 2, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0736
# Key-3-input: 0.0744
# Key-2-max3: 0.0418
# Key-2-max3: 0.0675
# Key-0-con1: 0.0788
# Key-2-max3: 0.0655
# Key-2-max3: 0.0643
# Key-1-con3: 0.0634
# Key-4-output: 0.0658
# Node importance to the global node:
#  [0.19384868 0.18966652 0.         0.20164514 0.         0.
#  0.19355246 0.         0.22128724]
# tensor([5, 3, 0, 2, 0, 0, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1026
# Key-3-input: 0.1004
# Key-0-con1: 0.0000
# Key-2-max3: 0.1068
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1025
# Key-0-con1: 0.0000
# Key-4-output: 0.1172
# Node importance to the global node:
#  [0.1310042  0.13794732 0.16257894 0.         0.16941836 0.10314131
#  0.1510562  0.         0.14485367]
# tensor([5, 3, 2, 0, 2, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0782
# Key-3-input: 0.0824
# Key-2-max3: 0.0971
# Key-0-con1: 0.0000
# Key-2-max3: 0.1012
# Key-1-con3: 0.0616
# Key-0-con1: 0.0902
# Key-0-con1: 0.0000
# Key-4-output: 0.0865
# Node importance to the global node:
#  [0.18066424 0.1716376  0.         0.10985977 0.15453635 0.09458501
#  0.0772045  0.11270348 0.09880906]
# tensor([5, 3, 0, 2, 1, 1, 2, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1076
# Key-3-input: 0.1023
# Key-0-con1: 0.0000
# Key-2-max3: 0.0655
# Key-1-con3: 0.0921
# Key-1-con3: 0.0564
# Key-2-max3: 0.0460
# Key-2-max3: 0.0672
# Key-4-output: 0.0589
# Node importance to the global node:
#  [0.1821275  0.14420095 0.         0.10962986 0.         0.17133433
#  0.         0.17978059 0.21292679]
# tensor([5, 3, 0, 1, 0, 2, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1089
# Key-3-input: 0.0862
# Key-0-con1: 0.0000
# Key-1-con3: 0.0656
# Key-0-con1: 0.0000
# Key-2-max3: 0.1025
# Key-0-con1: 0.0000
# Key-1-con3: 0.1075
# Key-4-output: 0.1273
# Node importance to the global node:
#  [0.17660286 0.15310156 0.17677137 0.         0.         0.07797696
#  0.13162354 0.0626199  0.22130382]
# tensor([5, 3, 1, 0, 0, 2, 1, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1053
# Key-3-input: 0.0913
# Key-1-con3: 0.1054
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0465
# Key-1-con3: 0.0785
# Key-1-con3: 0.0373
# Key-4-output: 0.1320
# Node importance to the global node:
#  [0.17658062 0.06990307 0.14261146 0.1207004  0.17802848 0.
#  0.09212626 0.11709986 0.10294986]
# tensor([5, 3, 1, 0, 0, 0, 1, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1032
# Key-3-input: 0.0409
# Key-1-con3: 0.0834
# Key-0-con1: 0.0705
# Key-0-con1: 0.1041
# Key-0-con1: 0.0000
# Key-1-con3: 0.0538
# Key-1-con3: 0.0684
# Key-4-output: 0.0602
# Node importance to the global node:
#  [0.19783726 0.13455595 0.12917988 0.         0.17977013 0.
#  0.         0.19215389 0.16650297]
# tensor([5, 3, 2, 0, 2, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1003
# Key-3-input: 0.0682
# Key-2-max3: 0.0655
# Key-0-con1: 0.0000
# Key-2-max3: 0.0911
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0974
# Key-4-output: 0.0844
# Node importance to the global node:
#  [0.10808724 0.0666477  0.13654836 0.03704158 0.18057017 0.09545933
#  0.18591735 0.07422099 0.11550737]
# tensor([5, 3, 0, 2, 2, 2, 1, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0644
# Key-3-input: 0.0397
# Key-0-con1: 0.0813
# Key-2-max3: 0.0221
# Key-2-max3: 0.1075
# Key-2-max3: 0.0569
# Key-1-con3: 0.1107
# Key-2-max3: 0.0442
# Key-4-output: 0.0688
# Node importance to the global node:
#  [0.25381997 0.25014502 0.         0.         0.         0.
#  0.         0.25193605 0.24409896]
# tensor([5, 3, 0, 0, 0, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1318
# Key-3-input: 0.1299
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1308
# Key-4-output: 0.1267
# Node importance to the global node:
#  [0.25580755 0.2538295  0.         0.         0.         0.
#  0.2432687  0.         0.24709426]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1327
# Key-3-input: 0.1317
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1262
# Key-0-con1: 0.0000
# Key-4-output: 0.1282
# Node importance to the global node:
#  [0.24709877 0.26093403 0.2500725  0.         0.         0.
#  0.         0.         0.24189468]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1282
# Key-3-input: 0.1354
# Key-0-con1: 0.1298
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1255
# Node importance to the global node:
#  [0.19289982 0.12368912 0.20400974 0.         0.18448329 0.
#  0.         0.17424156 0.1206765 ]
# tensor([5, 3, 1, 0, 0, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1152
# Key-3-input: 0.0739
# Key-1-con3: 0.1219
# Key-0-con1: 0.0000
# Key-0-con1: 0.1102
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1041
# Key-4-output: 0.0721
# Node importance to the global node:
#  [0.14905608 0.11414076 0.18781331 0.12981664 0.14371489 0.
#  0.         0.14978313 0.12567519]
# tensor([5, 3, 0, 2, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0855
# Key-3-input: 0.0655
# Key-0-con1: 0.1077
# Key-2-max3: 0.0745
# Key-0-con1: 0.0824
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0859
# Key-4-output: 0.0721
# Node importance to the global node:
#  [0.12990409 0.1335952  0.13041179 0.12141635 0.15288766 0.11581812
#  0.         0.15355429 0.06241241]
# tensor([5, 3, 2, 0, 1, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0775
# Key-3-input: 0.0797
# Key-2-max3: 0.0778
# Key-0-con1: 0.0724
# Key-1-con3: 0.0912
# Key-2-max3: 0.0691
# Key-0-con1: 0.0000
# Key-0-con1: 0.0916
# Key-4-output: 0.0372
# Node importance to the global node:
#  [0.19873911 0.19807518 0.         0.         0.         0.19707802
#  0.19741052 0.         0.20869718]
# tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1061
# Key-3-input: 0.1058
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1052
# Key-0-con1: 0.1054
# Key-0-con1: 0.0000
# Key-4-output: 0.1114
# Node importance to the global node:
#  [0.3541621  0.34277916 0.         0.         0.         0.
#  0.         0.         0.30305877]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1821
# Key-3-input: 0.1762
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1558
# Node importance to the global node:
#  [0.12489226 0.17266148 0.         0.09698838 0.19207446 0.
#  0.09768448 0.17270559 0.14299333]
# tensor([5, 3, 0, 2, 1, 0, 1, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0741
# Key-3-input: 0.1024
# Key-0-con1: 0.0000
# Key-2-max3: 0.0575
# Key-1-con3: 0.1139
# Key-0-con1: 0.0000
# Key-1-con3: 0.0579
# Key-2-max3: 0.1024
# Key-4-output: 0.0848
# Node importance to the global node:
#  [0.11406745 0.10686138 0.11493354 0.07639109 0.14095208 0.10171251
#  0.14404172 0.07568046 0.12535977]
# tensor([5, 3, 2, 0, 0, 0, 2, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0681
# Key-3-input: 0.0638
# Key-2-max3: 0.0686
# Key-0-con1: 0.0456
# Key-0-con1: 0.0842
# Key-0-con1: 0.0607
# Key-2-max3: 0.0860
# Key-2-max3: 0.0452
# Key-4-output: 0.0749
# Node importance to the global node:
#  [0.1651034  0.15586558 0.19932736 0.         0.         0.
#  0.16327341 0.15917979 0.15725045]
# tensor([5, 3, 2, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0897
# Key-3-input: 0.0847
# Key-2-max3: 0.1083
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0887
# Key-0-con1: 0.0865
# Key-4-output: 0.0854
# Node importance to the global node:
#  [0.32261658 0.32900476 0.         0.         0.         0.
#  0.         0.         0.34837866]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1659
# Key-3-input: 0.1692
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1791
# Node importance to the global node:
#  [0.13717148 0.1025437  0.07533935 0.11568125 0.12039556 0.08245166
#  0.13087946 0.09631841 0.13921918]
# tensor([5, 3, 2, 2, 0, 2, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0818
# Key-3-input: 0.0611
# Key-2-max3: 0.0449
# Key-2-max3: 0.0690
# Key-0-con1: 0.0718
# Key-2-max3: 0.0492
# Key-1-con3: 0.0780
# Key-0-con1: 0.0574
# Key-4-output: 0.0830
# Node importance to the global node:
#  [0.23885581 0.18492828 0.         0.         0.         0.19416574
#  0.         0.19859274 0.18345751]
# tensor([5, 3, 0, 0, 0, 2, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1282
# Key-3-input: 0.0993
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1042
# Key-0-con1: 0.0000
# Key-0-con1: 0.1066
# Key-4-output: 0.0985
# Node importance to the global node:
#  [0.149604   0.06951739 0.17228766 0.09644982 0.14066039 0.
#  0.1084943  0.1605371  0.1024493 ]
# tensor([5, 3, 1, 1, 0, 0, 2, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0891
# Key-3-input: 0.0414
# Key-1-con3: 0.1026
# Key-1-con3: 0.0574
# Key-0-con1: 0.0838
# Key-0-con1: 0.0000
# Key-2-max3: 0.0646
# Key-2-max3: 0.0956
# Key-4-output: 0.0610
# Node importance to the global node:
#  [0.25562248 0.24072257 0.         0.         0.         0.23956032
#  0.         0.         0.2640947 ]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1325
# Key-3-input: 0.1248
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.1242
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1369
# Node importance to the global node:
#  [0.12307782 0.15905936 0.13659918 0.12062717 0.         0.06625076
#  0.1447784  0.17415987 0.07544743]
# tensor([5, 3, 0, 2, 0, 0, 2, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0735
# Key-3-input: 0.0950
# Key-0-con1: 0.0816
# Key-2-max3: 0.0720
# Key-0-con1: 0.0000
# Key-0-con1: 0.0396
# Key-2-max3: 0.0864
# Key-1-con3: 0.1040
# Key-4-output: 0.0450
# Node importance to the global node:
#  [0.12104316 0.14165044 0.17442124 0.12994367 0.15367505 0.
#  0.         0.17296976 0.10629673]
# tensor([5, 3, 2, 1, 1, 0, 0, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0658
# Key-3-input: 0.0770
# Key-2-max3: 0.0949
# Key-1-con3: 0.0707
# Key-1-con3: 0.0836
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0941
# Key-4-output: 0.0578
# Node importance to the global node:
#  [0.17152919 0.09334023 0.12728098 0.09036706 0.2325032  0.09471434
#  0.         0.         0.19026509]
# tensor([5, 3, 1, 1, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1024
# Key-3-input: 0.0557
# Key-1-con3: 0.0760
# Key-1-con3: 0.0539
# Key-0-con1: 0.1388
# Key-1-con3: 0.0565
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1136
# Node importance to the global node:
#  [0.26198444 0.24980554 0.         0.24738586 0.         0.
#  0.         0.         0.24082412]
# tensor([5, 3, 0, 0, 0, 0, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1353
# Key-3-input: 0.1290
# Key-0-con1: 0.0000
# Key-0-con1: 0.1277
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1244
# Node importance to the global node:
#  [0.16443259 0.14132778 0.08986223 0.13384475 0.         0.
#  0.14699656 0.15458259 0.16895348]
# tensor([5, 3, 1, 2, 0, 0, 1, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0980
# Key-3-input: 0.0842
# Key-1-con3: 0.0535
# Key-2-max3: 0.0797
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.0876
# Key-2-max3: 0.0921
# Key-4-output: 0.1007
# Node importance to the global node:
#  [0.15438789 0.12281191 0.09049062 0.10633468 0.11339528 0.07944892
#  0.10546082 0.10984747 0.11782242]
# tensor([5, 3, 2, 1, 2, 1, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0921
# Key-3-input: 0.0733
# Key-2-max3: 0.0540
# Key-1-con3: 0.0634
# Key-2-max3: 0.0676
# Key-1-con3: 0.0474
# Key-1-con3: 0.0629
# Key-0-con1: 0.0655
# Key-4-output: 0.0703
# Node importance to the global node:
#  [0.16467097 0.17610916 0.22727066 0.         0.         0.
#  0.19033258 0.         0.2416166 ]
# tensor([5, 3, 1, 0, 0, 0, 2, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0940
# Key-3-input: 0.1005
# Key-1-con3: 0.1297
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1086
# Key-0-con1: 0.0000
# Key-4-output: 0.1379
# Node importance to the global node:
#  [0.25415486 0.22894725 0.         0.         0.         0.
#  0.         0.25198215 0.26491573]
# tensor([5, 3, 0, 0, 0, 0, 0, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1339
# Key-3-input: 0.1206
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.1328
# Key-4-output: 0.1396
# Node importance to the global node:
#  [0.12362394 0.09816366 0.         0.176823   0.         0.13735278
#  0.13427725 0.16463421 0.16512519]
# tensor([5, 3, 0, 2, 0, 2, 1, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0681
# Key-3-input: 0.0540
# Key-0-con1: 0.0000
# Key-2-max3: 0.0973
# Key-0-con1: 0.0000
# Key-2-max3: 0.0756
# Key-1-con3: 0.0739
# Key-0-con1: 0.0906
# Key-4-output: 0.0909
# Node importance to the global node:
#  [0.13910364 0.20601302 0.11793861 0.13622707 0.         0.
#  0.12475563 0.1587388  0.1172232 ]
# tensor([5, 3, 0, 2, 0, 0, 2, 2, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0797
# Key-3-input: 0.1181
# Key-0-con1: 0.0676
# Key-2-max3: 0.0781
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-2-max3: 0.0715
# Key-2-max3: 0.0910
# Key-4-output: 0.0672
# Node importance to the global node:
#  [0.1733934  0.05962108 0.2059413  0.         0.13841617 0.06150891
#  0.09171805 0.18342794 0.08597321]
# tensor([5, 3, 1, 0, 1, 1, 2, 1, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.0878
# Key-3-input: 0.0302
# Key-1-con3: 0.1043
# Key-0-con1: 0.0000
# Key-1-con3: 0.0701
# Key-1-con3: 0.0311
# Key-2-max3: 0.0464
# Key-1-con3: 0.0929
# Key-4-output: 0.0435
# Node importance to the global node:
#  [0.24687599 0.26059434 0.         0.         0.         0.24544135
#  0.         0.         0.24708839]
# tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall importance of each element in graph to the Global Node:
# Key-5-None: 0.1281
# Key-3-input: 0.1352
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-1-con3: 0.1273
# Key-0-con1: 0.0000
# Key-0-con1: 0.0000
# Key-4-output: 0.1282
# Node importance to the global node:
#  [0.24687599 0.26059434 0.         0.         0.         0.24544135
#  0.         0.         0.24708839]
# tensor: tensor([5, 3, 0, 0, 0, 1, 0, 0, 4])
# Overall average importance of each element in graph to the Global Node:
# Key-0-con1: 0.1969
# Key-1-con3: 0.1439
# Key-2-max3: 0.1413
# Key-3-input: 0.1441
# Key-4-output: 0.1579
# Key-5-None: 0.1412

# %%
for key, avg_value in average_importance.items():
    print(f"{average_importance[key] * 100:.2f}\%", end=' & ')
# Out:
# 19.69\% & 14.39\% & 14.13\% & 14.41\% & 15.79\% & 14.12\% &
